# %% [markdown]
# # Clean data from scraped reviews
# ## Import needed dependancies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
import nltk
import spacy
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
#nlp = spacy.load('en_core_web_md')
nlp = spacy.load('en_core_web_md')
wpt = nltk.WordPunctTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %%
# %matplotlib inline

# %%
# Import scraped reviews

# %%
# Review from Fertility IQ
df = pd.read_csv('../scrape/scraped_reviews.csv')

# %% [markdown]
# The data is scraped as questions and answers. The following code creates a single column for questions and a single column for answers.

# %%
df1 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 1','Answer 1']]
df1['Question'] = df1['Question 1']
df1['Answer']   = df1['Answer 1']
df2 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 2','Answer 2']]
df2['Question'] = df2['Question 2']
df2['Answer']   = df2['Answer 2']
df3 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 3','Answer 3']]
df3['Question'] = df3['Question 3']
df3['Answer']   = df3['Answer 3']
df4 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 4','Answer 4']]
df4['Question'] = df4['Question 4']
df4['Answer']   = df4['Answer 4']
df5 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 5','Answer 5']]
df5['Question'] = df5['Question 5']
df5['Answer']   = df5['Answer 5']
df6 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 6','Answer 6']]
df6['Question'] = df6['Question 6']
df6['Answer']   = df6['Answer 6']
df7 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 7','Answer 7']]
df7['Question'] = df7['Question 7']
df7['Answer']   = df7['Answer 7']
df8 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 8','Answer 8']]
df8['Question'] = df8['Question 8']
df8['Answer']   = df8['Answer 8']
df9 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 9','Answer 9']]
df9['Question'] = df9['Question 9']
df9['Answer']   = df9['Answer 9']
df10 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 10','Answer 10']]
df10['Question'] = df10['Question 10']
df10['Answer']   = df10['Answer 10']
# Out:
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_qa = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10], ignore_index=True)

# %%
df_t = df_qa.drop(['Question 1','Answer 1','Question 2','Answer 2','Question 3','Answer 3','Question 4','Answer 4',
                   'Question 5','Answer 5','Question 6','Answer 6','Question 7','Answer 7','Question 8','Answer 8',
                   'Question 9','Answer 9','Question 10','Answer 10'], axis=1)

# %%
# Remove columns
df_t = df_t.dropna().reset_index(drop=True)

# %%
def replace_q (val):
    if val[:28]=='How was your experience with':
        val = 'Doctor'   # classify under doctor
    elif val[:16] =='During treatment':  # Treated like num or human
        val = "Doctor"   # classify under doctor
    elif val[:16] == "What's one piece":
        val = 'Advice'
    elif val[:40] == "Describe your experience with your nurse":
        val = "Nurse"
    elif val[:42] == "Describe your experience with your nursing":
        val = "Nurse"
    elif val[:29]=="Describe your experience with":
        val = "Clinic"
    elif val[:22] == "Describe the protocols":
        val = "Protocols"
    elif val[:18]== "Describe the costs":
        val = "Cost"
    elif val[:31] == "What specific things went wrong":
        val = "Problems"
    else:
        if "eSET" in val:
            val = "Protocols"
        else:
            val=val
       
    return val

# %%
df_t.Question = df_t.Question.apply(replace_q)

# %%
for i,q in enumerate (df_t.Question.unique()):
    #if type(q)==float:
    print (i, q)
# Out:
# 0 Doctor
# 1 Advice
# 2 Nurse
# 3 Clinic
# 4 Protocols
# 5 Cost
# 6 Problems

# %% [markdown]
# The Scraped data from Fertility IQ needs special cleaning since it appears as html text. This will help further clean these responses.

# %%
def failed_list(text):
    if "<ul" in text:
        text_list = text.split(">")
        fail_list =[]
        for i in text_list:
            if "</li" in i:
                fail_list.append(i.split('<')[0])
        doc = ', '.join(fail_list)
        return doc
    
    else:
        return text

# %%
df_t.Answer = df_t.Answer.apply(failed_list)

# %%
#Save partially clean reviews to csv
df_t.to_csv('fiq_reviews.csv')

# %% [markdown]
# # Clean Text
# ## 1) Punctuation
# ## 2) Contractions
# ## 3) Stop Words
# ## 4) Lemetaziation

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
wpt = nltk.WordPunctTokenizer()
#wt = nltk.word_tokenizer()
#list of words to not remove
remove_form_stop_words = ['no','not',"aren't","couldn't","didn't","doesn't",
                          "wasn't","wouldn't","won't","don't","isn't","shouldn't"]
for w in remove_form_stop_words:
    en_stop.remove(w)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jacobberger/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
contractions = { 
"aren't": "are not,
"can't": "cannot",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"isn't": "is not",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"wasn't": "was not",
"weren't": "were not",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not"
}

# %%
def simple_clean_document(doc):
    # lower case and remove special characters\whitespaces
    #doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I|re.A)
    punc_list = ['.',',',"!",'*','?','-']
    
    doc = doc.lower()
    doc = doc.strip()
    
    doc = doc.split(" ")
    # Contractions in text 
    new_doc=[]
    for token in doc:
        if token in contractions:
            new_doc.append(contractions[token])
        else:
            new_doc.append(token)
    doc = ' '.join(new_doc)
    
    # tokenize document
    tokens = wpt.tokenize(doc)
    
    tokens = [token for token in tokens]
    # Contractions in text    
    for token in tokens:
        if token in contractions:
            token = contractions[token]
            
    # Remove Punctuation
    tokens = [token for token in tokens if token not in punc_list]
    
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in en_stop]
    
    #Lemmatize tokens
    lemm_tokens = [get_lemma(token) for token in filtered_tokens]
    
    # re-create document from filtered tokens
    doc = ' '.join(lemm_tokens)
    return doc

# %%
df_t['Clean_Text'] = df_t.Answer.apply(simple_clean_document)

# %%
df_t.to_csv('fiq_clean_text.csv')

# %%
nltk.download('wordnet')
from nltk.corpus import wordnet as wn

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer

def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jacobberger/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
get_lemma2(df_t.Answer[0])
# Out:
# "Dr. Rudick is very professional and knowledgeable. She never pushed me to do something I was not ready to do, and let me set the pace of my treatments. When I decided to take a short break between cycles, she was very understanding. She is also very straight forward and matter-of fact with results and reasons for those results, and she doesn't sugar-coat, which I appreciated and which added to my trust of her. When I received bad news after a few cycles back to back, Dr. Rudick sent me a very nice email and I felt that we were  in this together, working toward a common goal. Although Dr. Rudick was not always available at every visit, all of the doctors and nurses at Columbia were pleasant to work with. Before and during each procedure, Dr. Rudick would explain each step in detail, which helped ease my anxiety. I felt very cared for by her and the team at Columbia."

# %%
get_lemma(df_t.Answer[0])
# Out:
# "Dr. Rudick is very professional and knowledgeable. She never pushed me to do something I was not ready to do, and let me set the pace of my treatments. When I decided to take a short break between cycles, she was very understanding. She is also very straight forward and matter-of fact with results and reasons for those results, and she doesn't sugar-coat, which I appreciated and which added to my trust of her. When I received bad news after a few cycles back to back, Dr. Rudick sent me a very nice email and I felt that we were  in this together, working toward a common goal. Although Dr. Rudick was not always available at every visit, all of the doctors and nurses at Columbia were pleasant to work with. Before and during each procedure, Dr. Rudick would explain each step in detail, which helped ease my anxiety. I felt very cared for by her and the team at Columbia."

# %%
df_t.Answer[0]
# Out:
# "Dr. Rudick is very professional and knowledgeable. She never pushed me to do something I was not ready to do, and let me set the pace of my treatments. When I decided to take a short break between cycles, she was very understanding. She is also very straight forward and matter-of fact with results and reasons for those results, and she doesn't sugar-coat, which I appreciated and which added to my trust of her. When I received bad news after a few cycles back to back, Dr. Rudick sent me a very nice email and I felt that we were  in this together, working toward a common goal. Although Dr. Rudick was not always available at every visit, all of the doctors and nurses at Columbia were pleasant to work with. Before and during each procedure, Dr. Rudick would explain each step in detail, which helped ease my anxiety. I felt very cared for by her and the team at Columbia."

# %%
import spacy
nlp = spacy.load('en_core_web_md')

# %%
from spacy import displacy
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

# %%
# Function to clean scraped data
wpt = nltk.WordPunctTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    #doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I|re.A)
    punc_list = ['.',',',"!",'*','?','-']
    
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    #tokens = [token for token in tokens if token not in punc_list]
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    lemm_tokens = [get_lemma(token) for token in filtered_tokens]
    # re-create document from filtered tokens
    doc = ' '.join(lemm_tokens)
    return doc

# %%
normalize_document(df_t.Answer[0])
# Out:
# "dr . rudick professional knowledgeable . never push something not ready , let set pace treatment . decide take short break cycle , understanding . also straight forward matter - fact result reason result , ' sugar - coat , appreciate add trust . receive bad news cycle back back , dr . rudick sent nice email felt together , working toward common goal . although dr . rudick not always available every visit , doctor nurse columbia pleasant work . procedure , dr . rudick would explain step detail , help ease anxiety . felt care team columbia ."

# %%
normalize_document(df_t.Answer[0])
# Out:
# "dr . rudick professional knowledgeable . never pushed something not ready , let set pace treatments . decided take short break cycles , understanding . also straight forward matter - fact results reasons results , ' sugar - coat , appreciated added trust . received bad news cycles back back , dr . rudick sent nice email felt together , working toward common goal . although dr . rudick not always available every visit , doctors nurses columbia pleasant work . procedure , dr . rudick would explain step detail , helped ease anxiety . felt cared team columbia ."

# %%
df_t.Answer[0]
# Out:
# "Dr. Rudick is very professional and knowledgeable. She never pushed me to do something I was not ready to do, and let me set the pace of my treatments. When I decided to take a short break between cycles, she was very understanding. She is also very straight forward and matter-of fact with results and reasons for those results, and she doesn't sugar-coat, which I appreciated and which added to my trust of her. When I received bad news after a few cycles back to back, Dr. Rudick sent me a very nice email and I felt that we were  in this together, working toward a common goal. Although Dr. Rudick was not always available at every visit, all of the doctors and nurses at Columbia were pleasant to work with. Before and during each procedure, Dr. Rudick would explain each step in detail, which helped ease my anxiety. I felt very cared for by her and the team at Columbia."

# %%
sentences = list(intro_doc.sents)

# %%
sentences
# Out:
# [Dr. Rudick is very professional and knowledgeable.,
#  She never pushed me to do something I was not ready to do, and let me set the pace of my treatments.,
#  When I decided to take a short break between cycles, she was very understanding.,
#  She is also very straight forward and matter-of fact with results and reasons for those results, and she doesn't sugar-coat, which I appreciated and which added to my trust of her.,
#  When I received bad news after a few cycles back to back, Dr. Rudick sent me a very nice email and I felt that we were  in this together, working toward a common goal.,
#  Although Dr. Rudick was not always available at every visit, all of the doctors and nurses at Columbia were pleasant to work with.,
#  Before and during each procedure, Dr. Rudick would explain each step in detail, which helped ease my anxiety.,
#  I felt very cared for by her and the team at Columbia.]

# %%
def remove_punc(text):
    punc_list = ['.',',',"!",'*','?','-']
    text = ''.join(char for char in text if char not in punc_list)
    return text

# %%
#https://towardsdatascience.com/topic-modelling-in-python-with-nltk-and-gensim-4ef03213cd21
import spacy
spacy.load('en')
from spacy.lang.en import English
parser = English()

def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens


import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn

def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer

def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jacobberger/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jacobberger/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#list of words to not remove
remove_form_stop_words = ['no','not',"aren't","couldn't","didn't","doesn't",
                          "wasn't","wouldn't","won't","don't","isn't","shouldn't"]
for w in remove_form_stop_words:
    en_stop.remove(w)

# %%
def prepare_text_for_lda(text):
    
    text = remove_punc(text)
    
    tokens = tokenize(text)   

    # Remove Stop Words
    tokens = [token for token in tokens if token not in en_stop]
    #Lemmatization
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
df_answers = df_t.Answer.apply(prepare_text_for_lda)

# %% [markdown]
# # Cleaning data

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import spacy
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
#import en_core_web_lg

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import spacy
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en.stop_words import STOP_WORDS
nlp= spacy.load("en")
def lemmatizer(doc):
    # This takes in a doc of tokens from the NER and lemmatizes them. 
    # Pronouns (like "I" and "you" get lemmatized to '-PRON-', so I'm removing those.
    doc = [token.lemma_ for token in doc if token.lemma_ != '-PRON-']
    doc = u' '.join(doc)
    return nlp.make_doc(doc)
    
def remove_stopwords(doc):
    nlp= spacy.load("en")
    doc = nlp(doc)
    # This will remove stopwords and punctuation.
    # Use token.text to return strings, which we'll need for Gensim.
    doc = [token.text for token in doc if token.is_stop != True and token.is_punct != True]
    return doc

# %%
answer = df_t.Answer.apply(remove_stopwords)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-e9963d3ceb45> in <module>
# ----> 1 answer = df_t.Answer.apply(remove_stopwords)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-54-aeb2000f704e> in remove_stopwords(doc)
#      16
#      17 def remove_stopwords(doc):
# ---> 18     nlp= spacy.load("en")
#      19     doc = nlp(doc)
#      20     # This will remove stopwords and punctuation.
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/__init__.py in load(name, **overrides)
#      25     if depr_path not in (True, False, None):
#      26         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 27     return util.load_model(name, **overrides)
#      28
#      29
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model(name, **overrides)
#     130     if isinstance(name, basestring_):  # in data dir / shortcut
#     131         if name in set([d.name for d in data_path.iterdir()]):
# --> 132             return load_model_from_link(name, **overrides)
#     133         if is_package(name):  # installed as package
#     134             return load_model_from_package(name, **overrides)
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model_from_link(name, **overrides)
#     147     except AttributeError:
#     148         raise IOError(Errors.E051.format(name=name))
# --> 149     return cls.load(**overrides)
#     150
#     151
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/data/en/__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model_from_init_py(init_file, **overrides)
#     194     if not model_path.exists():
#     195         raise IOError(Errors.E052.format(path=path2str(data_path)))
# --> 196     return load_model_from_path(data_path, meta, **overrides)
#     197
#     198
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model_from_path(model_path, meta, **overrides)
#     165     lang = meta.get("lang_factory", meta["lang"])
#     166     cls = get_lang_class(lang)
# --> 167     nlp = cls(meta=meta, **overrides)
#     168     pipeline = meta.get("pipeline", [])
#     169     disable = overrides.get("disable", [])
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/language.py in __init__(self, vocab, make_doc, max_length, meta, **kwargs)
#     166         if make_doc is True:
#     167             factory = self.Defaults.create_tokenizer
# --> 168             make_doc = factory(self, **meta.get("tokenizer", {}))
#     169         self.tokenizer = make_doc
#     170         self.pipeline = []
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/language.py in create_tokenizer(cls, nlp)
#      78             suffix_search=suffix_search,
#      79             infix_finditer=infix_finditer,
# ---> 80             token_match=token_match,
#      81         )
#      82
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.__init__()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.add_special_case()
#
# vocab.pyx in spacy.vocab.Vocab.make_fused_token()
#
# vocab.pyx in spacy.vocab.Vocab.get_by_orth()
#
# vocab.pyx in spacy.vocab.Vocab._new_lexeme()
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/lang/lex_attrs.py in lower(string)
#     175
#     176
# --> 177 def lower(string):
#     178     return string.lower()
#     179
#
# KeyboardInterrupt:

# %%
def preprocessor(text):
    if type(text) == str:
        text = re.sub('<[^>]*>', '', text)
        text = re.sub('[\W]+', '', text.lower())
    return text



def spacy_clean_text(review):
                 
    nlp = English()
    tokenizer = nlp.Defaults.create_tokenizer(nlp)
    tokens = tokenizer(review)
    
    lemma_list = []
    n=0
    for token in tokens:
        if token.is_stop is False:
            token_preprocessed = preprocessor(token.lemma_)
            if token_preprocessed != '':
                lemma_list.append(token_preprocessed)
    text = ' '.join(lemma_list)           
    #return (lemma_list)
    return(text)

# %%
df_t['clean_answers'] = df_t.Answer.apply(spacy_clean_text)

# %%
df_t.to_csv('clean_reviews.csv')

# %%
def combine_token(text):
    text = ' '.join(text)
    return text

# %%
data['clean_text'] = data.token_answers.apply(combine_token)

# %%
df_t.clean_answers[0]
# Out:
# 'dr rudick professional knowledgeable push ready let set pace treatment decide short break cycle understand straight forward matt fact result reason result sugar coat appreciate add trust receive bad news cycle dr rudick send nice email feel work common goal dr rudick available visit doctor nurse columbia pleasant work procedure dr rudick explain step detail help ease anxiety feel care team columbia'

# %%
df_t
# Out:
#                  clinic_name  avg_clinic_score  avg_doc_score success  \
# 0        Columbia University               8.3            8.4     Yes
# 1        Columbia University               8.3            8.4       ?
# 2        Columbia University               8.3            8.4     Yes
# 3        Columbia University               8.3            8.4     Yes
# 4        Columbia University               8.3            8.4     Yes
# ...                      ...               ...            ...     ...
# 14825      RMA of New Jersey               9.1            9.1     Yes
# 14826      RMA of New Jersey               9.1            9.1     Yes
# 14827      RMA of New Jersey               9.1            9.1      No
# 14828    RMA of Philadelphia               8.5            8.5      No
# 14829  Main Line Fertility                 9.0            7.7     Yes
#
#               income  Question  \
# 0      $100K - $199K    Doctor
# 1      $200K - $499K    Doctor
# 2          $0 - $49K    Doctor
# 3      $100K - $199K    Doctor
# 4      $100K - $199K    Doctor
# ...              ...       ...
# 14825    $50K - $99K  Problems
# 14826    $50K - $99K  Problems
# 14827  $100K - $199K  Problems
# 14828  $100K - $199K  Problems
# 14829  $100K - $199K  Problems
#
#                                                   Answer  \
# 0      Dr. Rudick is very professional and knowledgea...
# 1      Dr. Forman listened to my concerns and is very...
# 2      There aren't enough words to describe how amaz...
# 3      The level of contact and patience he had for m...
# 4      As a physician myself, I was impressed with bo...
# ...                                                  ...
# 14825                                  Lost appointments
# 14826  Failed to order appropriate test, Failed to se...
# 14827                   Provided conflicting information
# 14828                   Provided conflicting information
# 14829                   Failed to order appropriate test
#
#                                               Clean_Text
# 0      dr rudick professional knowledgeable never pus...
# 1      dr forman listen concern good first time ivf p...
# 2      not / not enough words describe amaze dr eric ...
# 3      level contact patience patient go beyond docto...
# 4      physician impress dr brady ' clinical knowledg...
# ...                                                  ...
# 14825                                   lost appointment
# 14826  fail order appropriate test fail send chart an...
# 14827                       provide conflict information
# 14828                       provide conflict information
# 14829                        fail order appropriate test
#
# [14830 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
msg_train, msg_test, label_train, label_test = train_test_split(df_t.Clean_Text, df_t.Question, test_size=0.3)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vec = CountVectorizer()

# %%
data_vsc = vec.fit_transform(data.clean_text)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer = TfidfTransformer().fit_transform(data_bow)

# %%
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB

pipeline = Pipeline([
    ('bow', CountVectorizer()),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# %%
pipeline.fit(msg_train,label_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('classifier', MultinomialNB())])

# %%
predictions = pipeline.predict(msg_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(label_test,predictions))
print('\n')
print(classification_report(label_test,predictions))
# Out:
# [[ 132    0    0   46  367    0    1    0]
#  [   0  434    0   25   21    0    4    0]
#  [   1    2  123    2  107    0    9    0]
#  [   0    1    0  820  187    0    1    0]
#  [   0    0    0   60 1100    1    6    0]
#  [   0    0    0  131  164   11    0    0]
#  [   1    4    0    1   97    0  361    0]
#  [   0    0    0    0    0    0    0  175]]
#
#
#                                    precision    recall  f1-score   support
#
#   advice give prospective patient       0.99      0.24      0.39       546
#                              cost       0.98      0.90      0.94       484
# eSET vs. multiple embryo transfer       1.00      0.50      0.67       244
#            experience with clinic       0.76      0.81      0.78      1009
#            experience with doctor       0.54      0.94      0.69      1167
#             experience with nurse       0.92      0.04      0.07       306
#             protocols and success       0.95      0.78      0.85       464
#        specific things went wrong       1.00      1.00      1.00       175
#
#                          accuracy                           0.72      4395
#                         macro avg       0.89      0.65      0.67      4395
#                      weighted avg       0.81      0.72      0.69      4395

# %%
print(confusion_matrix(label_test,predictions))
print('\n')
print(classification_report(label_test,predictions))
# Out:
# [[ 113   57    0  365    1    0    1]
#  [   1  816    0  155    0    0    4]
#  [   0   16  426   20    0    0    7]
#  [   1   68    0 1123    0    0   16]
#  [   0  131    0  192   11    0    0]
#  [   0    0    0    0    0  173    0]
#  [   0    7    5  118    0    0  622]]
#
#
#               precision    recall  f1-score   support
#
#       Advice       0.98      0.21      0.35       537
#       Clinic       0.75      0.84      0.79       976
#         Cost       0.99      0.91      0.95       469
#       Doctor       0.57      0.93      0.71      1208
#        Nurse       0.92      0.03      0.06       334
#     Problems       1.00      1.00      1.00       173
#    Protocols       0.96      0.83      0.89       752
#
#     accuracy                           0.74      4449
#    macro avg       0.88      0.68      0.68      4449
# weighted avg       0.81      0.74      0.70      4449

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
SVM = svm.SVC(C=2) # default kernel = ’rbf’
rf = RandomForestClassifier()

# %%
pipeline = Pipeline([
    ('vec', CountVectorizer()),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', rf),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# %%
pipeline.fit(msg_train,label_train)
# Out:
# Pipeline(steps=[('vec', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('classifier', RandomForestClassifier())])

# %%
predictions = pipeline.predict(msg_test)

# %%
print(confusion_matrix(label_test,predictions))
print('\n')
print(classification_report(label_test,predictions))
# Out:
# [[ 360   49    6   96    3    0   23]
#  [  15  807    7   99   26    0   22]
#  [   1    8  437    2    0    1   20]
#  [  44   98    5 1017    3    1   40]
#  [  13  147    3  109   56    0    6]
#  [   0    0    0    0    0  173    0]
#  [  10    5   20   33    0    0  684]]
#
#
#               precision    recall  f1-score   support
#
#       Advice       0.81      0.67      0.73       537
#       Clinic       0.72      0.83      0.77       976
#         Cost       0.91      0.93      0.92       469
#       Doctor       0.75      0.84      0.79      1208
#        Nurse       0.64      0.17      0.27       334
#     Problems       0.99      1.00      0.99       173
#    Protocols       0.86      0.91      0.88       752
#
#     accuracy                           0.79      4449
#    macro avg       0.81      0.76      0.77      4449
# weighted avg       0.79      0.79      0.78      4449

# %% [markdown]
# # Clean Yelp Data

# %%
df_yelp = pd.read_csv('../scrape/yelp_reviews.csv')

# %%
# Break up setences
# Clean (stop_words and lemmatize)
#label with topics
# Out:
#      Unnamed: 0                    Clinic_name        Ratings  \
# 0             0  Columbia University Fertility  5 star rating
# 1             1  Columbia University Fertility  5 star rating
# 2             2  Columbia University Fertility  5 star rating
# 3             3  Columbia University Fertility  5 star rating
# 4             4  Columbia University Fertility  5 star rating
# ..          ...                            ...            ...
# 553         553            Penn Fertility Care  1 star rating
# 554         554            Penn Fertility Care  1 star rating
# 555         555            Penn Fertility Care  1 star rating
# 556         556            Penn Fertility Care  1 star rating
# 557         557            Penn Fertility Care  5 star rating
#
#                                                Reviews
# 0    Columbia University Fertility center is an exc...
# 1    There aren't enough words to describe how amaz...
# 2    We had an amazing experience. First of all the...
# 3    I had a great experience with Columbia Fertili...
# 4    We had a wonderful experience at Columbia Univ...
# ..                                                 ...
# 553  My interaction with one of the doctora as this...
# 554  Absolutely horrible. The wait here is simply u...
# 555  Penn fertility is absolutely terrible.  We wen...
# 556  First, I should be clear that my experiences w...
# 557  Penn Fertility Care has been knowledgeable, in...
#
# [558 rows x 4 columns]

# %%
for i, rev in enumerate (df_yelp.Reviews):
    for n in re.findall(r'[\u4e00-\u9fff]+', rev):
        print(i,n)
# Out:
# 129 首先
# 129 我要感谢刘子涛医生和他在新希望生育中心的团队
# 129 我从没想过我需要去生育中心
# 129 直到我组建了新家庭
# 129 我的丈夫有一个愿望已经超过
# 129 年了
# 129 他现在有一个十几岁的儿子
# 129 年前他失去了他的新生女婴
# 129 虽然他很爱他的儿子
# 129 他仍然希望有一个女儿去爱
# 129 我感受到了他的痛苦
# 129 为了不让他生活在深深的遗憾中
# 129 我们决定生个女儿扩大我们的家庭
# 129 但由于我们年过中年
# 129 我们需要帮助
# 129 我们认为有医生的帮助怀孕是一个相当简单的过程
# 129 在开始试管受精之前
# 129 我和丈夫搜寻了在纽约的很多诊所
# 129 新希望
# 129 似乎是我们最好的选择
# 129 我
# 129 多岁的妹妹在新希望的帮助下得到了她的儿子
# 129 她的结果给了我们更多的勇气
# 129 然而我们的情况并不是那么顺利
# 129 我们从冷冻到新鲜
# 129 每次失败也会抱头痛哭
# 129 在我们一无所措时
# 129 刘医生给了我们很多支持
# 129 当我们有了囊胚
# 129 基因测试结果又都是男孩
# 129 我们感到很不幸
# 129 因为上帝一次又一次没有给我们想要的
# 129 当我们再次尝试
# 129 得到的基因检测结果是
# 129 的部分非整倍体
# 129 自然我们变得焦虑和沮丧
# 129 刘医生尽他最大的努力给予了我们帮助
# 129 他知识渊博
# 129 友好
# 129 超级专业
# 129 随着他渊博的专业经验
# 129 我们的梦想终于实现了
# 129 是的
# 129 这是一个漫长的旅程
# 129 但我们对结果很满意
# 129 感谢他的团队的支持
# 129 让我们度过了那些艰难的时刻
# 129 再次感谢刘医生和您的团队

# %%
df_yelp = df_yelp.drop(129,axis=0)
df_yelp.reset_index(inplace=True)
# Out:
#                        Clinic_name        Ratings  \
# 0    Columbia University Fertility  5 star rating
# 1    Columbia University Fertility  5 star rating
# 2    Columbia University Fertility  5 star rating
# 3    Columbia University Fertility  5 star rating
# 4    Columbia University Fertility  5 star rating
# ..                             ...            ...
# 552            Penn Fertility Care  1 star rating
# 553            Penn Fertility Care  1 star rating
# 554            Penn Fertility Care  1 star rating
# 555            Penn Fertility Care  1 star rating
# 556            Penn Fertility Care  5 star rating
#
#                                                Reviews
# 0    Columbia University Fertility center is an exc...
# 1    There aren't enough words to describe how amaz...
# 2    We had an amazing experience. First of all the...
# 3    I had a great experience with Columbia Fertili...
# 4    We had a wonderful experience at Columbia Univ...
# ..                                                 ...
# 552  My interaction with one of the doctora as this...
# 553  Absolutely horrible. The wait here is simply u...
# 554  Penn fertility is absolutely terrible.  We wen...
# 555  First, I should be clear that my experiences w...
# 556  Penn Fertility Care has been knowledgeable, in...
#
# [557 rows x 3 columns]

# %%
df_yelp = df_yelp.drop(['Unnamed: 0','index'],axis=1)

# %%
def split_up_review(df):
    df_final = pd.DataFrame()
    for c in df.Clinic_name.unique():
        
        df_temp = df[df.Clinic_name == c]
        
        
        sentences = []
        #id = c + "_" + str(0)
        for i, r in enumerate (df_temp.Reviews):
            list_of_sentences = r.replace("Dr.","Dr").split(".")
        
            sentences = sentences + list_of_sentences
            #print(i,c)
            
        df_new = pd.DataFrame(sentences,columns=['Reviews_by_sentence'])
        df_new['Clinic'] = c
        df_final = pd.concat([df_final,df_new],ignore_index=True)
        
    return df_final

# %%
df_yelp_split = split_up_review(df_yelp)
len(df_yelp_split)
# Out:
# 6820

# %%
for r in df_yelp_split.Reviews_by_sentence:
    if r == "often":
        print (True)
df_yelp_split.Reviews_by_sentence[149]
# Out:
# ' Being a teacher, the monitoring hours worked for me and they were able to accommodate me by giving me one of the first appointments'

# %%
sns.countplot(df_yelp_split.Clinic)

# %%
for i, r in enumerate (df_yelp_split.Reviews_by_sentence):
    if len(r) < 15:
        print (r)
        df_yelp_split.drop(i,axis=0,inplace=True)
# Out:
# It took us 4
#
#
#
#
#
#
#
# )
#
#
# p
# s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  PS
# m
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Wish me luck!
#
#
#
#   Ok fine
#
#
#
#
#
#
#
#
#
#
#
#
#
#  run
#
#
#
#
#
#
# Hello again
#
#
#
#
#
#
#
#
#
#
#
# 2
# 3
# 5
#  Good luck!
#
#
#
# Good hours
#  Liu and Merhi
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# twice
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  They're busy
#
#
#
#
#
#
#
#
#
#
#   Not the case
# org)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# e
#
#  Never did
#  Jessica
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  doi: 10
# 1016/j
# rbmo
# 2011
# 05
# 018
# "
#
#
#  It isn't
#
#
#
#  "natural"
#
#
#
#
#
#
#
#
#
#
#
#  Good
#  And soon
#
#
#
#
#
#
#
#
#
#
#
#
#  be ware
# be ware!!!!!!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5)
# 5 dosage
#
#
# 1
# 2
#   4
#  5
#  6
#  Extraction
# 7
# 8
#  9
# 10
# 11
#
#
#
# ]
#
#
#  Demand this
#
# ny
#
#
#
#
#
#
#  e
# g
#
#
#
#
#
#
# g
#
#
# B
#   Ugh
#
#
#
#
#
#
#
#
#
#
#
#
#
#  GREAT
#
#  I don't know
#
#
#
#
#
#
#
#
#
#
#  Thank you!!!!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  :)
#
#
# m
# m
#  clinic hours
#  And very kind
# m
#
#
#
# D
#  Bull, RN, BSN
#
#
#
#
#
#
#
#
#
#  Too sad
#
#
#
#
#
#
#
#
#
#
#
#     P
# S
#
#
#
#
#
#
#
#
#
#  My TSH was 3
#
#
#
#
#
#
# Gee
#
#
#
#
#
#
#
# e
#
#
#  2 years ago
#
#
#
#
#
#
#
#
#
# I liked RMA
#  My dr
# 5
#
#
#
#   DO NOT GO
#
#
#
# 4
#
#
#
#
#
#
#
#
# anywhere else
#
#
#
#
#
#
#
#
#
#
# The
# Only
# Call
# I
# Got
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   And
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Now the staff
#
#
#
#
#
#
#
#
#
#
#
#  en
# wikipedia
#  I don't know
#
#
#
#
#
#
# )
#
#
#
#   Stay away!!!
#
#
# 1
#  3
# 4
# 6
#
#
#
#
#
# 1
#
#
#
#
#
#
# 4
#
#
#
#
#
#
#
#
#
#
#
#
# Please avoid
#   1
# 2
#   3
#   4
#
#
#
#
#  Wrong
#
#
# S
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Xoxox
#
#
#
#
#
#
#
#
#
#  Thank you
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Everything
#  Dr
#
#
#  1
# 2
# 3
#  4
# 5
#
#  But billing?
#
#  Good luck
#
#
#
#
#  Be careful
#
#
#
# I love Dr T
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  It was a mess
#  Night and day
#
#
#
#  Or, call
#   Not once
#
#   Nothing
#
#
#
#
#
#
#
#
#
#
#
#
#   And Dr T
#
#
#
#
#
#  He's amazing
#
#
#
#
#
#
#
#  The staff
#  Dayna
#  And I did
#
#
#
#
#
# com/news/loca…
#
#
#
# S
#
#
#
#
#
#
#
# they do
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wow
#
#
#
# not
#  Oh
#
#
#
#
#
#
#  They do care
#
#   They stink!
#
#
#
#
#
#  Barnabas
#  Barnabas
#
#
#
#
#
#
#
#
#
# 1
# 2
# 3
# 5
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10 STARS
#
#
#
#
#
#
#
#
# 5 years ago
#
#
#
#
#
#
#
#
# Go here
#   Good luck!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# g
#
#
# g
#  RMA)
#
#
#
#
# A
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Zero response
#  Nothing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c…
#
#
#
#
#
#
#
# m
#
# e
#
#
#
#  Okay

# %%
len(df_yelp_split)
# Out:
# 5902

# %%
df_yelp_split.Reviews_by_sentence[148]
# Out:
# ' This communication is above and beyond and the whole team at Columbia never made me feel like there was a silly or stupid question'

# %% [markdown]
# # Add columm for clean yelp data

# %%
df_yelp_split['original_answers'] = df_yelp_split.Reviews_by_sentence
df_yelp_split['clean_answers'] = df_yelp_split.Reviews_by_sentence

# %%
df_yelp_split.clean_answers = df_yelp_split.clean_answers.apply(spacy_clean_text)

# %%
df_yelp_split[['clean_answers','original_answers']].head()
# Out:
#                                        clean_answers  \
# 0  columbia university fertility center excellent...
# 1      see dr paula brady columbia university clinic
# 2      excellent doctor treat patient personal level
# 3                      dr brady take care work great
# 4  clinic good open patient holiday weekend new y...
#
#                                     original_answers
# 0  Columbia University Fertility center is an exc...
# 1   We were seen by Dr Paula Brady at the Columbi...
# 2   She is an excellent doctor, who treats her pa...
# 3   Dr Brady took care of us and everything worke...
# 4  The Clinic as a whole is also very good as it ...

# %%
df_yelp_split.reset_index(drop=True,inplace=True)

# %%
for r in df_yelp_split.clean_answers:
    print (r)
# Out:
# columbia university fertility center excellent fertility clinic wonderful team doctor
# see dr paula brady columbia university clinic
# excellent doctor treat patient personal level
# dr brady take care work great
# clinic good open patient holiday weekend new year holiday
# entire team dr brady helpful professional listen patient concern care issue properly take care
# short notice quickly
# wish 5 star especially dr brady excellent consultant great human
# bother issue great significance quickly email phone
# reply email sunday
# consider patient human understand design program accordingly patient individually base specific requirement patient
# prepare road map patient follow till end like
# ambiguous plan make simple clear
# especially mention stressful corona pandemic manage ensure effect grateful
# expert field knowledgeable care provider field expertise
# inspire way
# god depute angel form human angel work help distress people personal level
# feel honor patient
# make comfortable entire procedure ensure stress phase way
# go need medication need support kind word medical team
# feel low feel nervous issue contact dr brady reply fine well pretty normal feel great feel good early
# word pretty simple normal english believe come physician distress work wonder dr brady great communicate way line act healer
# way dr brady thing body believe pretty normal important treatment
# consider fertility program sincerely advise consult columbia fertility look dr brady well resource
# advice patient trust judgement team believe well
# word describe amaze dr eric forman staff columbia fertility center
# husband try conceive year have luck
# change meet dr forman
# dr forman break process step step procedure sure understand
# overall process lengthy able conceive round ivf
# dr forman take time explain answer question feel rush
# able contact dr forman time receive quick reply email phone
# atmosphere columbia fertility center warm welcome
# nice atmosphere experience doctor office
# thank dr forman help parent amaze baby boy
# amaze experience
# place positive light energy
# entire stuff smile
# point remind explain
# feel like
# stress confusion
# know expect decide fertility center
# honestly go smooth hustle free
# confusion know step way
# probably non overwhelm doctor experience
# long story short month successful ivf try doctor work incredible favorite far dr brady
# definitely come baby 2 dr brady incredibly knowledgeable professional supportive super sweet
# touch entire team
# update day appointment
# outstanding level care professionalism decide switch doctor columbia doctor
# update initial review
# try baby 2 disappoint experience
# know get busy pregnancy time matt fate
# moment need doc ofcourse happen
# cycle fail nurse advise meet dr zhang step
# doc need viable embryo
# wish get well care
# feel like nurse handle care time consult doctor
# great facility good experience staff care ivf journey
# process undergo procedure hopeful
# setback anesthesia
# facility let patient home hour ivf sedation
# sign waiver end procedure state go home
# understand patient home especially procedure schedule day
# need change dangerous suboptimal delivery care
# maybe provide chaperone stress importance have home procedure
# rate zero
# facility waste time money
# doctor follow case nurse send email say doctor say
# start year ago follicle reach size 15 year late detect
# feel know
# numb care customize
# leave exam table wait doctor explain year late follicle
# leave unattended exam table
# physician come appointment
# 30 minute decide leave realize forget
# hours past call go restroom leave
# false hope facility string come sense
# entire year see doctor 4 time
# great overall fertility center huge staff s will help
# sonogrophers nurse particularly knowledgeable great come ultrasound morning
# end see dr olcha great hold hand process
# nhfc approach care
# persistently call speak embryo call day
# single person call
# spite repeat call plead time sensitive issue question silence nhfc
# place need advocate hope well
# billing department vigilant chase invoice wish doctor
# fed place
# call matt journey treatment
# get call doctor people process insurance bill
# go ie process insurance pharmacythe doctor
# find place
# wait call need round meds desperately
# process time try process needlessly excruciating frustrate expensive
# feel like assembly line wait room like dmv literally wait numb call
# disappoint sell hope realistically stats number come slowly reveal little hopeful realistic
# dr merhi lovely
# straightforward give practical advice situation follow successful natural iui try
# finish 4th cycle
# take break mentally prepare
# 4th cycle experience restart cycle 2 time
# let explain
# know want doctor follow case
# request doctor monitor
# get instruction monitor expect instruction
# ask clomid
# follow monitor tell follicle go
# doctor speak
# tell monitor continue birth control pill email instruction
# doctorpart 4th cycle
# take birth control pill
# follicle recruitment expect
# ask doctor follow
# follow instruction clomid gonal
# not want repeat history
# stern take medication
# asked speak doctor
# good response
# purchase gonal expensive
# results follicle lose
# disappoint expect
# finally get speak doctor
# nice phone ask try
# 4th cycle
# end result
# find doctor monitor like request
# doctor admit doctor look case vacation
# doctor know wife reaction clomid
# recommend clomid intake high time burn follicle
# come talk till ready 5th cycle
# doctor busy
# want think happy thought
# nhfc work lot couple today
# doctor busy egg retrieval
# nhfc work
# get good bad indifferent result pm
# want learn experience ask maybe conversation invaluable
# wish well
# come start family grow family
# journey wish experience good
# time seek treatment
# explain respond inquiry zero personal attention
# numb factory
# treat big fertility clinic nj go new hope
# recommend treatment donor egg consultation clinic nj treatment start 43
# go conventional 2 ivfs decide change clinic depress hopeless blastocyst
# clinic nj feel pressure use donor egg uncomfortable continue treatment age
# ivf nhfc get blastocyst give hope
# journey long difficult door nhfc close dr zhang recommend mini ivfs medication body mind peaceful comfortable cycle
# like nhfc nhfc doctor listen work patient
# see bad review bill dept fine maybe study insurance know need charge
# question bill go bill staff get answer
# finally get good blastocyst 45 year old transfer get pregnant baby 46 year old
# great thank dr zhang dr lui joanna nurse chisa embryologist support difficulty journey life change miracle baby oo
# especially old like egg conventional ivfs highly recommend nhfc
# dr merhi new hope fertility center refer fertility treatment
# go husband consultation spring 2018 decide forward ivf procedure month late summer
# initial visit fall love dr merhi
# attentive patient care comfort personable great sense humor
# husband difficulty process simple process
# dr merhi amaze extremely attentive patient strategic help overcome hurdle encounter
# entire team nhfc extremely professional helpful
# communication nhfc awesome communication confidential email system respect schedule follow appointment provide test result
# staff truly work team address patient
# love procedure house bloodwork sonogram embryo transfer collect sperm specimen etc
# medical facility organize doctor forward think mindset research expertise
# work new breakthrough well help patient
# emphasize patient center great bedside manner important
# bonus early morning hour start 7 open 7 day week
# easy work appointment work schedule time
# happy report 10 week pregnant 1st embryo transfer
# husband happy dr merhi take time ensure high success rate possible
# rush component procedure take little long expect
# plan have child definitely know return nhfc doubt
# sad visit new hope graduate care feel leave knowledge need help phase pregnancy
# new hope treat like numb like cog assembly line human
# allow speak doctor see main doctor regularly get know
# mass process result carelessness
# numb care live die suffer care number money
# shame shame shame dr zhang
# follow dr zaher merhi
# diagnose pcos probably simple condition treat
# long story short visit amaze happy start process
# problem start
# visit ultrasound blood test nurse tell need pill bc ovulate
# 10 minute visit doctor tell wait period start pill stimulate ovulation
# nurse ultrasound say ovulate
# try spend money
# month try dr suggest ivf want bc truly believe old way baby pcos
# listen dr beautiful daughter
# 2 start bc place clean beautiful nurse super friendly super kind
# instead people work desk rude emergency
# want money
# wish good luck journey try listen doctor
# bc sadly want money
# dr merhi patient amazing cycle external circumstance need stop travel home texas family
# ride elevator sweet blonde woman ask feel
# visibly disappoint
# think strange mind business
# realize work would hide introduce director marketing jaclyn
# speak feel well decision choose nhfc
# help figure situation term cycle financially 10 minute
# believe involve quickly take action
# case thank work
# experience incredible despite circumstance dr merhi office soon return
# thought advice1
# choosing doctor important choose clinic
# work dr yang think well
# protocol personalize dr yang follow patient begin end
# furthermore experience surgeon
# conduct procedure patient
# tell patient skip cycle vacation
# try use email need prescription send bill question
# find phone call frustrate time incredibly busy
# ask doctor method communication prefer
# save lot anxiety
# complaint nh nurse communication
# instruction look communicate doctor sure dosage time right
# critical prior retrieval transfer
# try find ivf partner wait room
# need emotional support 4
# consult family doctor 2 opinion abnormal blood result test run report available
# set eye help
# wellbeing important future baby
# positive think easy journey treat
# stay happy stay strong
# dr zaher merhi great answer question timely manner
# success dr merhi happy decide new hope mini ivf cycle
# currently 10 week pregnant twins happy thank dr merhi new hope staff
# email time inquire response
# call reception take numb
# show office answer
# pretty bad communication
# time respond question monitor email result reply email question like medication quantity
# outside will hear
# doctor kulp makarov well fertility doctor ask
# patient understand kind
# help stay hopeful tough moment
# talented ask effective knowledgeable
# thank completely change live dr makarov
# new hope special place
# visit fertility doctor tell need use donor egg give age egg quality
# previous ivf cycle render egg
# doctor new hope different perspective
# try medication yay gentle approach
# take bank eventually get viable embryo
# big thank staff vision nhfc
# amazing think outside box
# send email customer service enquire service
# response
# reply administrator handle account yelp
# end give go service provider
# handle customer service able new customer
# efficient staff clinic
# dr merhi sympathetic knowledgable doctor help quick visit
# practice will work retrieval egg case successful cycle get egg pgs test 29 week pregnant
# place will push donor
# work dr
# prefer dr liu find responsive will discuss question concern
# acknowledge mistake cycle cancel give free cycle
# go long way term deal emotional disappointment
# cons billing department pretty bad poor communication skill follow mean spend lot time email call go person address mistake end
# twice phone call email respond
# unlike weill cornell nurse assign
# instruction give different nurse
# find bite frustrate explain specific issue concern question
# yelp review like appropriate place review facility
# know outlet review come make important decision
# want long journey year expensive worth 9 week pregnant
# give dr zaher merhi give encouragement prayer give strength press truly grateful
# place modern nice people work nice bunch
# people desk helpful rigid think
# frustrate talk try explain stuff schedule
# nurse staff okay well
# girl heavy chinese accent ask repeatedly say get angry
# well experience
# lastly wait long time time
# wife wait 2 hour multiple occassions show time appointment
# suggest try luck place decide
# dr yang patient go great doctor give confident hope far
# well unfortunately kick new hope fertility center
# middle egg retrieval process start stimulate egg
# new hope fertility center give notification follow case instruction
# communication solution management clinic suck
# response new hope representative perfect example mislead practice clinic
# consideration travel schedule
# clear travel date ignore completely
# sit go schedule
# information need successful cycle provide
# importantly easy blame woman body clinic failure
# ready response failure
# birth control schedule start cycle appointment london
# time hormone cycle control birth control
# cycle start
# pure incompetence likely general disinterest patient need response blame woman body
# cycle fail produce desire result tell body
# failure step cycle
# inform decision experience ivf
# freeze egg extend fertility
# undergo similar procedure state
# retrieve 24 egg clinic
# new hope retrieve 6
# real number
# difference competency
# able produce 14 follicle naturally proper stimulation give fertility history hormone panel able produce considerably stimulation
# barring failure stimulate properly retrieval get 6 14 egg
# average clinic able retrieve statistical average 70 egg
# clinic claim extraordinary number able retrieve half egg able produce
# numb friend undergo process clinic retrieval rate sit 40
# exclude point false promise unethical process undue stress
# interest cycle process extend fertility undergo ivf child economically incentivized produce positive outcome try
# ask woman invest financially physically medically temporally process measure let measure ensure ideal outcome behalf entirely unethical
# women mother deserve well
# sure woman hesitant speak experience personal private medical process
# happy putt experience internet believe process importance woman newfound ability extend fertility face modern career family challenge
# business found run own man
# interest woman experience need process essential
# update review
# baby boy perfect
# highly recommend nhfc think have child have difficulty
# terrible business practice
# stay away clinic
# contact new hope hope get information case
# send form fill
# tell need phone
# morning receive early morning
# go questionnaire 5 minute
# send invoice 350 usd say consultation agree call agree charge medical discuss
# 2 day row come place 900 appointment
# day experience incompetence desk mismanagement great
# know friend visit fertility clinic procedure wife great experience
# time hassle
# new hope
# wait total 8 hour long expect
# appointments mean absolutely place
# desk attendant recognize 2 day reservation system
# tell line occasion hour pass
# concept schedule office management 101 completely foreign place
# apology misinformation receive lengthy wait
# office let medical office manage terrible disorganize way instill little confidence go wait room
# review intend reflect poorly doctor medical staff good thing family
# complaint ire solely direct management staff perform job horribly
# negative star experience
# positive experience egg freeze new hope
# initial conference dr zhang pleasant
# staff extremely polite professional time go
# wait long
# immaculately clean love aromatherapy scent air
# able freeze 22 egg
# 39 time
# retrieval anxiety produce feel rush
# end freeze egg nhfc rest treatment
# bad experience different fertility clinic ny change new hope
# dr zhang impression kind honest enthusiastic knowledgeable aggressive program
# exactly right approach work 1month old baby boy
# stressful journey ivf end perfectly nhfc
# find surrounding nice tea coffee reception examination procedure room feel new clean well experience previous clinic
# staff nice system work open early good work schedule flexible need
# wife japanese approach environment lend asian feel feel comfortable respect
# negative people personal touch mechanical operation issue personally
# example speak different nurse doctor way have dedicate
# finally feel cost reasonable soft aggressive approach easy pocket medication point cap cost visit month mean afraid come worry want need nurse fear charge
# cost system easy hide fear
# feel comfortable pay pocket
# overall recommend new hope speak ivf ny
# wrong bill department call 4 time 3 week ask pay bill line service drzhang overzealous get ivf
# tell need ivf right away statistically fertility fall cliff explain husband try conceive 3 month get naturally pregnant miscarriage time
# decide pass ivf naturally pregnant healthy baby 9 month late
# feel get month new hope want administer ivf patient possible generally medically possible need
# come dose drug trigger ovulation test ovulatory disorder
# positive experience lab tech nurse
# update year settle account start receive bill
# service render june 2014 include doctor consultation minor lab work
# reach bill department ask itemize bill explain charge tell bill forgive
# s nice
# ...
# bump star rate 35 result
# 2016 university pennsylvania fertility disaster
# individually nurse doctor resident receptionist extremely competent kind system place run like dmv 1980
# promise doctor probably doctor
# receive call
# person familiarity concern case
# specific medical concern need remind single medical professional read chart
# way update current information
# gay single definitely explicitly implicitly discriminate ask husband multiple occasion
# disregard review decide sure ask question think step process
# help advocate extra mile
# run seriously run deal incompetent group people life
# wife choose penn unfortunately read google yelp review
# 100 accurate start penn summer 2018
# wait 3 month appointment edwards
# time see doctor
# 14 16 month discuss treatment plan revolve door nurse
# makes feel real confident
# unpleasant surprise
# wife hsg test
# point explain essentially bill surgery procedure
# fun surprise 2400 dollar bill show deductible
# research avg price hsg philadelphia 400 600
# penn cost 4 5x avg city
# start notice charge 2 co pay visit 2 separate doctor
# edwards see 16 month doctor hear
# single visit charge 120 dollar
# hsg determine wife block tube
# medical history lead happen offer explanation occur
# fun fact tube block goof apparently figure test month wife come office 4 6 time month monitor size follicle
# mind operate assumption pregnant right dominate
# month look close 500 dollar co pay constant ultrasound final straw
# approve iui treatment insurance
# wife come yay follicle leave
# tell come 2 day late measure follicle
# 2 day late right dominate
# interest 2 day prior apparently follicle right
# revolve door nurse
# nurse walk celebrate apparently know wife right tube block unfortunately clue thank medical expert penn
# lose shit snap woman
# work sale live meet client know piece info
# get well
# wife apparently right dominate month
# nurse look say come 2 day check
# go 120 dollar
# 2 day late office magically leave follicle disappear know wife ovulate
# nurse think wife right tube block say hey maybe try iui month
# waste procedure limit numb will work know ovulate
# visit choose different fertility clinic highly recommend
# magically co pay 40 visit charge double
# told sure bill twice visit
# 4 visit time actual doctor
# best consultation sit bewilder wife chart understand fuck penn try
# figure wife tube block
# seriously run fuck away place
# horrible experience
# primarily sale pl likedocs normally
# definitely return penn fertility
# tell price fertility treatment range average idea whatsoever cost unlesswe complete thousand dollar test wthem
# take business
# wehave appointment mainline fertility w dr glassner
# suppose well area
# steer clear penn want appointment like deal salesman gym
# wife ordeal go penn fertility frequently follicle check know trigger shoot release egg
# week go friday follicle 17 mm nurse nicole tell trigger shoot day night
# wife ask nurse confirm normally take 18 mm nurse confirm
# wife take shoot 5 pm
# 515 pm get phone different person confirm instruction instruction shoot saturday
# incredibly frustrate
# frustrate send leave multiple message weekend inquire happen affect chance cycle
# awful customer service tough situation
# like dr rarely doc
# negative experience penn fertility
# wait month period fibroid grow crazily take clomid fsh double amh drop 60 clomid speed egg reserve
# call nurse notify severe effect heavy bleed belly pain ask stop clomid say continue ibuprofen feel pain
# unprofessional
# search medicine online effect happen patient notify doctor stop medicine immediately
# fact doctor script hormone levothyroxine thyroid disorder take clomid will lead ovulation actually result heavy bleed
# nurse friendly
# blood test ultra sound exam charge separately expensive
# doctor care money give unnecessary surgery
# want know polyp body like tell
# want know ultrasound result clomid mess uterus ovary say want ultrasound result home nurse tell
# fact tell
# help destroy reproduction system lot bill
# good experience dr barnhart nurse switch main line fertility cancel cycle
# dr barnhart switch protocol successful
# ivf pregnancy end miscarriage pleasant work
# nurse shower compliment sympathy loss
# return 7 week ultrasound check
# call office numerous question nurse answer
# dr coutifaris perform retrieval show sense humor write numb embryo retrieve hand
# dr dokras perform transfer thorough talk
# work dr butts laparoscopy
# recommend
# especially endometriosis
# go iui tell 20 minute late doctor need city
# tell sample hour case time occasion nurse laugh talk infertility
# place need sensitivity professionalism train
# treat disrespect lack compassion stressful painful time
# treat like numb test straight iui
# practice disgrace
# husband go dr dokras infertility treatment
# refer penn fetal medicine fantastic experience
# continue high opinion penn fetal medicine
# terrible experience dr dokras
# uneducated unsympathetic need
# initial appointment decide fertility center philadelphia
# amaze experience fertility center
# recommend facility
# shock disappoint lack knowledge attention sensitivity experience
# great facility treat respect care deserve
# unfortunately
# leave review practice experience like previous reviewer
# wonderful compassionate timely care office 3701 market street
# patient office year
# doctor dr dokras
# actually head receptionist madeline teresa incredibly kind interaction person phone
# yes wait 25 minute occasion norm
# visit include visit blood work wait 5 minute
# reason doctor upenn teach hospital office fellowship program doctor instructor
# fellow currently physician field wonderful bedside manner extremely important fertility patient
# experience fellow thorough communicative attend physician compassionate
# visit fellow doctor
# request doctor prefer
# find see doctor great work team care
# head well onei nurse nurse susan rock day visit follow care
# detail instruction plan important fertility patient
# dismiss office previous review check
# love like
# mean scathing mean dr butts wish assign doctor kind nurse
# majority penn fertility staff treat husband terribly difficult time
# run standard battery test charge twice explain
# fail iui procedure time penn charge co pay 150 specimen thaw co pay fertility clinic
# touch doctor nurse want time rush phone
# receptionist rude unintelligent unhelpful
# final straw test show fallopian tube blockage mean procedure possibly complete waste time tear money doctor tell
# look report research unfamiliar medical term interpret report
# husband go shady grove fertility thrill switch
# leave practice december receive harass enormous bill resolve
# penn abuse try rob
# clinic human decency incredibly emotional try time
# switch mainline fertility wise choice
# give 5 star wait time well offer 7
# lab time office
# receive respect superb care desk staff doctor
# main dr dr barnhart wonderful receive care dr butts dr dokras dr coutafaris misspell head doctor
# get run mainline change protocol immediately figure milk money insurance pay ivf dr barnhart review history change protocol go smoothly
# 4 day past 3 day embryo transfer
# dr dokras let view screen transfer explain step step
# severe endo issue high estrogen low ovarian reserve 34yrs old dr dokras transfer 2 grade 1 8 cell embryo
# expect positive pregnancy test week
# cute negative review practice dismiss recommend
# actually contain valuable point patient
# overall level service uneven
# give place nickname hot mess happy end
# miscommunicate
# completely forget come fro initial appointment casually 45 minute past schedule time have review chart
# occasionally wrong dose med
# stay 450 unit dose actually 300 unit prepare doublecheck step
# pleasant heart right place system overall effective
# think 24 hour retrieval tell donor sperm prepare
# mean airhead nurse bother check day procedure sunday afternoon
# honestly bite
# end find sperm procedure minute gown iv know procedure happen
# prepare lot stress omission
# achieve result close group center city people geographically important bloodwork day
# people like dr shah kalra garcia nurse erin rie professional tech think julie receptionist actually treat nice accomodating need early train cut line coupla time
# keeba biller approachable help wrongly file bill
# egg donor
# amaze wait 5 minute wait room
# nurse take blood amazing feel bruise treat respect care
# experience doctor actually time know care health problem donate love
# please penn fertility
# interview fertility clinic ultimately choose penn happy
# sex couple need egg donor surrogate
# party coordinator amaze help coordinate move piece surrogacy journey kink throw unexpectedly
# dr g gem help work typical situation arise
# available process need
# incredibly appreciate emotional process
# ultimately successful pregnancy try baby year visit clinic
# happy moon little bundle joy
# plan penn big brother soon
# interaction doctora practive leave feel dismiss unvalued
# discussion ivf come inform dr option me shut
# comment fix age pregnant
# conversation reply go nature course
# bedside manner unprofessional pelvic exam advise insert speculum finger
# tell visit er day prior unusual discharge tell stop take antibiotic tell take intercourse night let know issue persist
# thatm say fine pretty sure fine post
# prusing ivf believe practice well country recommend dr sondheimer
# absolutely horrible
# wait simply unprofessional uncall
# fiancé attend penn fertility year
# extremely distraught experience miscarriage fail iui
# deal unpleasant receptionist sit room 30 90mins wait doctor nurse incredibly frustrate
# especially multiple time week
# avoid center city location cost
# doctor drbutts knowledgable barely rush interaction leave question concern
# run lengthy trial know fail finally prescribe correctly
# thing expect result basically bug
# place complete waste time
# avoid possible
# penn fertility absolutely terrible
# go 8 month barely run test husband
# see doctor twice usually nurse dr
# hsg
# ask try fertility meds month recommend mention nurse give explanation
# feel completely unmonitored
# blood test ultrasound month
# little oversight
# clear experience exclusively 3701 market street location
# initial visit radnor want care website location interchangeable yes right
# having come fertility practice see doctor visit shock doctor doctor nurse visit
# comfortable arrangement feel easy access nurse doctor way feel disconnect care power ask simple question feedback
# doctor nurse fine review give 3 12 4 star
# sway regular visit office 1 star
# wait terrible 25 minute hour
# maybe big deal doctor office fertility test occur day need able quickly
# case get blood work take 2 minute
# previous clinic usually wait 10 min wrong wait 4 month 30 minute apologetic
# penn fertility
# wait well ask question
# reason low rate receptionist
# quiet follower typer personality happy tell long mistreat
# main receptionist 3701 penn fertility care nasty woman meet
# bark time come
# great day away desk office step possess common courtesy
# like small thing guard dog office nearly impossible talk get past
# singlehandedly visit incredibly frustrate unpleasant stressful b c undergo fertility treatment duh
# insurance require penn fertility care choice
# choice suggest run practice try rma
# penn fertility care knowledgeable informative flexible husband navigate tricky fertility process
# middle treatment pregnant consider go else sense number think care individual patient case try develop protocol work individual
# individualize bill approaches explain bill ask person come receive random disconnect bill
# doctor excellent get treatment inclement weather mean doctor switch schedules available
# nurse staff way
# nurse communicate text need realize process nurse important feel comfortable nurse

# %%
for i, r in enumerate (df_yelp_split.clean_answers):
    if len(r) < 10:
        print (r)
        df_yelp_split.drop(i,axis=0,inplace=True)
# Out:
# feel like
# family
# recommend
# great
# thank
# happy far
# nhfc try
# care
# know talk
# money mo
# care
# let pcos
# wait mum
# rate zero
# feel know
# fed place
# 4th cycle
# nhfc work
# wish well
# response
# work dr
# new hope
# wait long
# 39 time
# s nice
# busy time
# 100 worth
# good luck
# honest
# hormone
# deal care
# feel
# like tell
# expect
#
# infuriate
#
# idea
# star
# feel rush
# wile take
# comfort
# home
#
# email
# time pass
# hear
# think odd
# 3rd work
# penny
#
# watch
# wait long
#
# excellent
# mean
# 5 go 5 7
# important
# positive
# factory
# guy quit
# hear
# bizarre
# stressful
# thank nyu
# extract
#
# tiny
# try worry
# job
# know
# nyu well
# let well
# team
# time
# thank
# afternoon
# treat 7
# place a
# calls
# shame
# cash cow
# patience
# pregnant
# rma wrong
# fantastic
# want dr
# 4 star
# wish 4
# find fax
# rma tell
# ivf glad
# glad
# u kid
# place
# like hate
# horrible
# recommend
# stressful
# agree say
# get
# go
# pron pron
# believe
# recommend
# crazy
# work
# stop go
#
# etiquette
# forget
# cancer
# ask hurt
# zero star
# nice cry
# numb
# say
# kid
# doctor 2
# star dr
# lightly
# work
# love
# place
# stress
# brilliant
# best wish
# hear like
#
# charge
#
# get well
# pay
# helpful
# ask
# crook
# ti work
# thank
# care
# clinic
# wrong
# office
# bad place
#
# okay
#
# let
#
# care
# advice
# pregnant
# nurse day
# good hand
# hope
# patience
# question
# believe
# best luck
# know
# sort
# waste 30k
# numb
# wait
# use
# butcher
# fool
# spouse
#
# great job
# zero star
# work find
# go sure
# go leave
# numb
# cold rude
# love doc
# favor
#
# properly
#
# meet pa
# best luck
# big issue
# 200 even
# unwilling
# run late
#
# thank
# story
# get well
# line
# fact tell
# recommend
# love like
# egg donor
# hsg

# %%
df_yelp_split.to_csv('yelp_clean.csv')

# %%
df_clean = pd.read_csv('clean_reviews.csv')

# %%
df_clean.clean_answers[0]
# Out:
# 'dr rudick professional knowledgeable push ready let set pace treatment decide short break cycle understand straight forward matt fact result reason result sugar coat appreciate add trust receive bad news cycle dr rudick send nice email feel work common goal dr rudick available visit doctor nurse columbia pleasant work procedure dr rudick explain step detail help ease anxiety feel care team columbia'

# %%
df_clean.Answer[0]
# Out:
# "Dr. Rudick is very professional and knowledgeable. She never pushed me to do something I was not ready to do, and let me set the pace of my treatments. When I decided to take a short break between cycles, she was very understanding. She is also very straight forward and matter-of fact with results and reasons for those results, and she doesn't sugar-coat, which I appreciated and which added to my trust of her. When I received bad news after a few cycles back to back, Dr. Rudick sent me a very nice email and I felt that we were  in this together, working toward a common goal. Although Dr. Rudick was not always available at every visit, all of the doctors and nurses at Columbia were pleasant to work with. Before and during each procedure, Dr. Rudick would explain each step in detail, which helped ease my anxiety. I felt very cared for by her and the team at Columbia."

# %%
df_t.Clean_Text[0]
# Out:
# 'dr rudick professional knowledgeable never push something not ready let set pace treatment decide take short break cycle understanding also straight forward matter fact result reason result not sugar coat appreciate add trust receive bad news cycle back back dr rudick sent nice email felt together working toward common goal although dr rudick not always available every visit doctor nurse columbia pleasant work procedure dr rudick would explain step detail help ease anxiety felt care team columbia'
