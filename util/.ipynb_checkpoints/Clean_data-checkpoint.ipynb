# %% [markdown]
# # Clean data from scraped reviews
# ## Import needed dependancies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
import nltk
import spacy
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
#nlp = spacy.load('en_core_web_md')
nlp = spacy.load('en_core_web_md')
wpt = nltk.WordPunctTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %%
# %matplotlib inline

# %%
# Import scraped reviews

# %%
# Review from Fertility IQ
df = pd.read_csv('../scrape/scraped_reviews.csv')

# %% [markdown]
# The data is scraped as questions and answers. The following code creates a single column for questions and a single column for answers.

# %%
df1 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 1','Answer 1']]
df1['Question'] = df1['Question 1']
df1['Answer']   = df1['Answer 1']
df2 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 2','Answer 2']]
df2['Question'] = df2['Question 2']
df2['Answer']   = df2['Answer 2']
df3 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 3','Answer 3']]
df3['Question'] = df3['Question 3']
df3['Answer']   = df3['Answer 3']
df4 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 4','Answer 4']]
df4['Question'] = df4['Question 4']
df4['Answer']   = df4['Answer 4']
df5 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 5','Answer 5']]
df5['Question'] = df5['Question 5']
df5['Answer']   = df5['Answer 5']
df6 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 6','Answer 6']]
df6['Question'] = df6['Question 6']
df6['Answer']   = df6['Answer 6']
df7 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 7','Answer 7']]
df7['Question'] = df7['Question 7']
df7['Answer']   = df7['Answer 7']
df8 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 8','Answer 8']]
df8['Question'] = df8['Question 8']
df8['Answer']   = df8['Answer 8']
df9 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 9','Answer 9']]
df9['Question'] = df9['Question 9']
df9['Answer']   = df9['Answer 9']
df10 = df[['clinic_name','avg_clinic_score','avg_doc_score','success','income','Question 10','Answer 10']]
df10['Question'] = df10['Question 10']
df10['Answer']   = df10['Answer 10']
# Out:
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/jacobberger/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_qa = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10], ignore_index=True)

# %%
df_qa = df_qa.drop(['Question 1','Answer 1','Question 2','Answer 2','Question 3','Answer 3','Question 4','Answer 4',
                   'Question 5','Answer 5','Question 6','Answer 6','Question 7','Answer 7','Question 8','Answer 8',
                   'Question 9','Answer 9','Question 10','Answer 10'], axis=1)

# %%
# Remove columns
df_qa = df_qa.dropna().reset_index(drop=True)

# %%
def replace_q (val):
    if val[:28]=='How was your experience with':
        val = 'Doctor'   # classify under doctor
    elif val[:16] =='During treatment':  # Treated like num or human
        val = "Doctor"   # classify under doctor
    elif val[:16] == "What's one piece":
        val = 'Advice'
    elif val[:40] == "Describe your experience with your nurse":
        val = "Nurse"
    elif val[:42] == "Describe your experience with your nursing":
        val = "Nurse"
    elif val[:29]=="Describe your experience with":
        val = "Clinic"
    elif val[:22] == "Describe the protocols":
        val = "Protocols"
    elif val[:18]== "Describe the costs":
        val = "Cost"
    elif val[:31] == "What specific things went wrong":
        val = "Problems"
    else:
        if "eSET" in val:
            val = "Protocols"
        else:
            val=val
       
    return val

# %%
df_qa.Question = df_qa.Question.apply(replace_q)

# %%
for i,q in enumerate (df_t.Question.unique()):
    #if type(q)==float:
    print (i, q)
# Out:
# 0 Doctor
# 1 Advice
# 2 Nurse
# 3 Clinic
# 4 Protocols
# 5 Cost
# 6 Problems

# %% [markdown]
# The Scraped data from Fertility IQ needs special cleaning since it appears as html text. This will help further clean these responses.

# %%
def failed_list(text):
    if "<ul" in text:
        text_list = text.split(">")
        fail_list =[]
        for i in text_list:
            if "</li" in i:
                fail_list.append(i.split('<')[0])
        doc = ', '.join(fail_list)
        return doc
    
    else:
        return text

# %%
df_t.Answer = df_t.Answer.apply(failed_list)

# %%
#Save partially clean reviews to csv
df_t.to_csv('fiq_reviews.csv')

# %% [markdown]
# # Clean Text
# ## 1) Punctuation
# ## 2) Contractions
# ## 3) Stop Words
# ## 4) Lemetaziation

# %%
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
en_stop = set(nltk.corpus.stopwords.words('english'))
wpt = nltk.WordPunctTokenizer()
#wt = nltk.word_tokenizer()
#list of words to not remove
remove_form_stop_words = ['no','not',"aren't","couldn't","didn't","doesn't",
                          "wasn't","wouldn't","won't","don't","isn't","shouldn't"]
for w in remove_form_stop_words:
    en_stop.remove(w)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jacobberger/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
contractions = { 
"aren't": "are not,
"can't": "cannot",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"isn't": "is not",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"wasn't": "was not",
"weren't": "were not",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not"
}

# %%
def simple_clean_document(doc):
    # lower case and remove special characters\whitespaces
    #doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I|re.A)
    punc_list = ['.',',',"!",'*','?','-','/','"',"(",")"]
    
    doc = doc.lower()
    doc = doc.strip()
    
    doc = doc.split(" ")
    # Contractions in text 
    new_doc=[]
    for token in doc:
        if token in contractions:
            new_doc.append(contractions[token])
        else:
            new_doc.append(token)
    doc = ' '.join(new_doc)
    
    # tokenize document
    tokens = wpt.tokenize(doc)
    
    tokens = [token for token in tokens]
    # Contractions in text    
    for token in tokens:
        if token in contractions:
            token = contractions[token]
            
    # Remove Punctuation
    tokens = [token for token in tokens if token not in punc_list]
    
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in en_stop]
    
    #Lemmatize tokens
    lemm_tokens = [get_lemma(token) for token in filtered_tokens]
    
    # re-create document from filtered tokens
    doc = ' '.join(lemm_tokens)
    return doc

# %%
df_t['Clean_Text'] = df_t.Answer.apply(simple_clean_document)

# %%
df_t.to_csv('fiq_clean_text.csv')

# %%
# OLD TEXT CLEANING PROCESS
#def preprocessor(text):
#    if type(text) == str:
#        text = re.sub('<[^>]*>', '', text)
#        text = re.sub('[\W]+', '', text.lower())
#    return text



#def spacy_clean_text(review):
                 
#    nlp = English()
#    tokenizer = nlp.Defaults.create_tokenizer(nlp)
#    tokens = tokenizer(review)
    
#    lemma_list = []
#    n=0
#    for token in tokens:
#        if token.is_stop is False:
#            token_preprocessed = preprocessor(token.lemma_)
#            if token_preprocessed != '':
#                lemma_list.append(token_preprocessed)
#    text = ' '.join(lemma_list)           
#    #return (lemma_list)
#    return(text)

# %%
from sklearn.model_selection import train_test_split

# %%
msg_train, msg_test, label_train, label_test = train_test_split(df_t.Clean_Text, df_t.Question, test_size=0.3)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vec = CountVectorizer()

# %%
data_vsc = vec.fit_transform(data.clean_text)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer = TfidfTransformer().fit_transform(data_bow)

# %%
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB

pipeline = Pipeline([
    ('bow', CountVectorizer()),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# %%
pipeline.fit(msg_train,label_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('classifier', MultinomialNB())])

# %%
predictions = pipeline.predict(msg_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(label_test,predictions))
print('\n')
print(classification_report(label_test,predictions))
# Out:
# [[ 132    0    0   46  367    0    1    0]
#  [   0  434    0   25   21    0    4    0]
#  [   1    2  123    2  107    0    9    0]
#  [   0    1    0  820  187    0    1    0]
#  [   0    0    0   60 1100    1    6    0]
#  [   0    0    0  131  164   11    0    0]
#  [   1    4    0    1   97    0  361    0]
#  [   0    0    0    0    0    0    0  175]]
#
#
#                                    precision    recall  f1-score   support
#
#   advice give prospective patient       0.99      0.24      0.39       546
#                              cost       0.98      0.90      0.94       484
# eSET vs. multiple embryo transfer       1.00      0.50      0.67       244
#            experience with clinic       0.76      0.81      0.78      1009
#            experience with doctor       0.54      0.94      0.69      1167
#             experience with nurse       0.92      0.04      0.07       306
#             protocols and success       0.95      0.78      0.85       464
#        specific things went wrong       1.00      1.00      1.00       175
#
#                          accuracy                           0.72      4395
#                         macro avg       0.89      0.65      0.67      4395
#                      weighted avg       0.81      0.72      0.69      4395

# %%
print(confusion_matrix(label_test,predictions))
print('\n')
print(classification_report(label_test,predictions))
# Out:
# [[ 113   57    0  365    1    0    1]
#  [   1  816    0  155    0    0    4]
#  [   0   16  426   20    0    0    7]
#  [   1   68    0 1123    0    0   16]
#  [   0  131    0  192   11    0    0]
#  [   0    0    0    0    0  173    0]
#  [   0    7    5  118    0    0  622]]
#
#
#               precision    recall  f1-score   support
#
#       Advice       0.98      0.21      0.35       537
#       Clinic       0.75      0.84      0.79       976
#         Cost       0.99      0.91      0.95       469
#       Doctor       0.57      0.93      0.71      1208
#        Nurse       0.92      0.03      0.06       334
#     Problems       1.00      1.00      1.00       173
#    Protocols       0.96      0.83      0.89       752
#
#     accuracy                           0.74      4449
#    macro avg       0.88      0.68      0.68      4449
# weighted avg       0.81      0.74      0.70      4449

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
SVM = svm.SVC(C=2) # default kernel = ’rbf’
rf = RandomForestClassifier()

# %%
pipeline = Pipeline([
    ('vec', CountVectorizer()),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', rf),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# %%
pipeline.fit(msg_train,label_train)
# Out:
# Pipeline(steps=[('vec', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('classifier', RandomForestClassifier())])

# %%
predictions = pipeline.predict(msg_test)

# %%
print(confusion_matrix(label_test,predictions))
print('\n')
print(classification_report(label_test,predictions))
# Out:
# [[ 360   49    6   96    3    0   23]
#  [  15  807    7   99   26    0   22]
#  [   1    8  437    2    0    1   20]
#  [  44   98    5 1017    3    1   40]
#  [  13  147    3  109   56    0    6]
#  [   0    0    0    0    0  173    0]
#  [  10    5   20   33    0    0  684]]
#
#
#               precision    recall  f1-score   support
#
#       Advice       0.81      0.67      0.73       537
#       Clinic       0.72      0.83      0.77       976
#         Cost       0.91      0.93      0.92       469
#       Doctor       0.75      0.84      0.79      1208
#        Nurse       0.64      0.17      0.27       334
#     Problems       0.99      1.00      0.99       173
#    Protocols       0.86      0.91      0.88       752
#
#     accuracy                           0.79      4449
#    macro avg       0.81      0.76      0.77      4449
# weighted avg       0.79      0.79      0.78      4449

# %% [markdown]
# # Clean Yelp Data

# %%
df_yelp = pd.read_csv('../scrape/yelp_reviews.csv')

# %%
df_yelp
# Out:
#      Unnamed: 0                    Clinic_name        Ratings  \
# 0             0  Columbia University Fertility  5 star rating
# 1             1  Columbia University Fertility  5 star rating
# 2             2  Columbia University Fertility  5 star rating
# 3             3  Columbia University Fertility  5 star rating
# 4             4  Columbia University Fertility  5 star rating
# ..          ...                            ...            ...
# 553         553            Penn Fertility Care  1 star rating
# 554         554            Penn Fertility Care  1 star rating
# 555         555            Penn Fertility Care  1 star rating
# 556         556            Penn Fertility Care  1 star rating
# 557         557            Penn Fertility Care  5 star rating
#
#                                                Reviews
# 0    Columbia University Fertility center is an exc...
# 1    There aren't enough words to describe how amaz...
# 2    We had an amazing experience. First of all the...
# 3    I had a great experience with Columbia Fertili...
# 4    We had a wonderful experience at Columbia Univ...
# ..                                                 ...
# 553  My interaction with one of the doctora as this...
# 554  Absolutely horrible. The wait here is simply u...
# 555  Penn fertility is absolutely terrible.  We wen...
# 556  First, I should be clear that my experiences w...
# 557  Penn Fertility Care has been knowledgeable, in...
#
# [558 rows x 4 columns]

# %%
for i, rev in enumerate (df_yelp.Reviews):
    char = False
    for n in re.findall(r'[\u4e00-\u9fff]+', rev):
        char = True
        #print(i,n)
    if char:
        df_yelp = df_yelp.drop(i,axis=0)
        char = False

# %%
#df_yelp = df_yelp.drop(129,axis=0)
df_yelp.reset_index(inplace=True)

# %%
df_yelp = df_yelp.drop(['Unnamed: 0','index'],axis=1)

# %%
def split_up_review(df):
    df_final = pd.DataFrame()
    for c in df.Clinic_name.unique():
        
        df_temp = df[df.Clinic_name == c]
        
        
        sentences = []
        #id = c + "_" + str(0)
        for i, r in enumerate (df_temp.Reviews):
            list_of_sentences = r.replace("Dr.","Dr").strip().split(".")
        
            sentences = sentences + list_of_sentences
            #print(i,c)
            
        df_new = pd.DataFrame(sentences,columns=['Reviews_by_sentence'])
        df_new['Clinic'] = c
        df_final = pd.concat([df_final,df_new],ignore_index=True)
        
    return df_final

# %%
df_yelp_split = split_up_review(df_yelp)
len(df_yelp_split)
# Out:
# 6820

# %%
df_yelp_split.Reviews_by_sentence[184]
# Out:
# ')'

# %%
for i, r in enumerate (df_yelp_split.Reviews_by_sentence):
    if len(r) < 11:
        #print (i,r)
        df_yelp_split.drop(i,axis=0,inplace=True)

# %%
len(df_yelp_split)
# Out:
# 5939

# %%
df_yelp_split.reset_index(drop=True,inplace=True)

# %%
df_yelp_split
# Out:
#                                     Reviews_by_sentence  \
# 0     Columbia University Fertility center is an exc...
# 1      We were seen by Dr Paula Brady at the Columbi...
# 2      She is an excellent doctor, who treats her pa...
# 3      Dr Brady took care of us and everything worke...
# 4     The Clinic as a whole is also very good as it ...
# ...                                                 ...
# 5934   I'm in the middle of my treatments with them ...
# 5935   They have also been individualized in their b...
# 5936   The doctors are all excellent-- we've gotten ...
# 5937                  The nursing staff is the same way
# 5938   My nurse communicates via text when I need to...
#
#                              Clinic  \
# 0     Columbia University Fertility
# 1     Columbia University Fertility
# 2     Columbia University Fertility
# 3     Columbia University Fertility
# 4     Columbia University Fertility
# ...                             ...
# 5934            Penn Fertility Care
# 5935            Penn Fertility Care
# 5936            Penn Fertility Care
# 5937            Penn Fertility Care
# 5938            Penn Fertility Care
#
#                                           clean_answers
# 0     columbia university fertility center excellent...
# 1         see dr paula brady columbia university clinic
# 2         excellent doctor treat patient personal level
# 3        dr brady take care us everything work great us
# 4     clinic whole also good open patient holiday we...
# ...                                                 ...
# 5934  ' middle treatment not pregnant yet never cons...
# 5935  also individualize billing approach -- explain...
# 5936  doctor excellent -- get treatment inclement we...
# 5937                                  nursing staff way
# 5938  nurse communicate via text need although not r...
#
# [5939 rows x 3 columns]

# %% [markdown]
# # Add columm for clean yelp data

# %%
#df_yelp_split.clean_answers = df_yelp_split.clean_answers.apply(spacy_clean_text)
df_yelp_split['clean_answers'] = df_yelp_split.Reviews_by_sentence.apply(simple_clean_document)

# %%
df_yelp_split[['clean_answers','Reviews_by_sentence']].head()
# Out:
#                                        clean_answers  \
# 0  columbia university fertility center excellent...
# 1      see dr paula brady columbia university clinic
# 2      excellent doctor treat patient personal level
# 3     dr brady take care us everything work great us
# 4  clinic whole also good open patient holiday we...
#
#                                  Reviews_by_sentence
# 0  Columbia University Fertility center is an exc...
# 1   We were seen by Dr Paula Brady at the Columbi...
# 2   She is an excellent doctor, who treats her pa...
# 3   Dr Brady took care of us and everything worke...
# 4  The Clinic as a whole is also very good as it ...

# %%
df_yelp_split.Reviews_by_sentence[77]
# Out:
# '5 years to get pregnant! I had some uterus issues, and we did 2 egg retrievals and 3 embryo transfers (3rd one worked!)'

# %%
df_yelp_split.clean_answers[77]
# Out:
# '5 years get pregnant uterus issue 2 egg retrieval 3 embryo transfer ( 3rd one work !)'

# %%
for i,r in enumerate(df_yelp_split.clean_answers):
    print (i,r)
# Out:
# 0 columbia university fertility center excellent fertility clinic wonderful team doctor
# 1 see dr paula brady columbia university clinic
# 2 excellent doctor treat patient personal level
# 3 dr brady take care us everything work great us
# 4 clinic whole also good open patient holiday weekend even new year holiday
# 5 entire team dr brady helpful professional listen patient concern care issue properly take care
# 6 even call short notice get back quite quickly
# 7 wish could give 5 star especially dr brady excellent consultant great human
# 8 would often bother issue may not great significance would always get back quickly either email phone
# 9 would even reply email sunday
# 10 consider patient humans understand design program accordingly patient individually base specific requirement patient
# 11 prepare road map patient follow till end really like
# 12 nothing ambiguous plan make everything simple clear
# 13 would especially mention even stressful corona pandemic really manage everything well ensure not effect anyway really grateful
# 14 expert field knowledgeable care provider field expertise
# 15 one inspire many ways
# 16 god depute angel form humans one angel working help distress people personal level
# 17 felt honor patient
# 18 make comfortable entire procedure ensure not stress phase way
# 19 going not need medication also need support kind words medical team well
# 20 felt low felt nervous issue would contact dr brady would reply " ' fine " " get better " " pretty normal " make feel great even not feeling good earlier
# 21 words may seem pretty simple normal english believe coming physician distress works wonder dr brady great communicating way line would act healer
# 22 way dr brady use say things make body believe " pretty normal " important treatment
# 23 anyone consider fertility program would sincerely advise consult columbia fertility look dr brady best resource
# 24 one last advice become patient trust judgement team believe " get better "
# 25 not / not enough words describe amaze dr eric forman staff columbia fertility center
# 26 husband try conceive years not luck
# 27 change meet dr forman
# 28 dr forman break process step step procedure make sure understand
# 29 overall process lengthy able conceive first round ivf
# 30 dr forman always take time explain answer question never make us feel rush
# 31 able contact dr forman time always receive quick reply whether email phone
# 32 atmosphere columbia fertility center warm welcome
# 33 nice atmosphere ever experience doctor ' office
# 34 thank dr forman helping us become parent amaze baby boy
# 35 amaze experience
# 36 first whole place positive light energy
# 37 entire stuff always smiling
# 38 everyone point not remind explain anything anyone
# 39 felt like everything do us
# 40 no stress no confusion
# 41 not know expect first decide go fertility center
# 42 honestly go smooth hustle free
# 43 no confusion know next every step way
# 44 probably non overwhelm doctor experience ever
# 45 long story short several month successful ivf first try :) every doctor work incredible favorite far dr brady
# 46 definitely coming back baby # 2 :) dr brady incredibly knowledgeable professional supportive super sweet
# 47 always touch entire team top everything
# 48 always update day appointment
# 49 outstanding level care professionalism decide switch doctor columbia doctor
# 50 great experience columbia fertility doctor staff couple years
# 51 staff friendly felt like extend family going up down occur fertility woe
# 52 interact attentive responsive front desk staff nursing staff back office staff doctor
# 53 course two years many interact would call names not want leave anyone happy day " graduate " release ob gyn hug high fives staff dr forman fast forward almost year later ' first time parent happy healthy baby girl
# 54 thanks part effort former cwrc aka columbia university fertility
# 55 ' happy chosen columbia address fertility issue years ago
# 56 wonderful experience columbia university fertility center
# 57 dr karipcin amaze lucky
# 58 / caring compassionate doctor
# 59 answer question concern
# 60 supportive going forward ivf felt confident care
# 61 definitely go back decide 2nd baby
# 62 husband decide columbia stumble upon insanely high review dr forman via blog post ( review stalking fertility iq )
# 63 dr forman entire columbia fertility staff nice people shall / ever come across throughout fertility journey
# 64 office space bright clean employee constantly smiling no matter time day communication process cannot beat
# 65 wait time appointment either nonexistent extremely low consider doctor office '
# 66 dr forman open book fast response rate pretty much anyone ' ever email period
# 67 no question dumb small
# 68 get stressful process truly everything make feel comfortable well inform possible
# 69 specific logistical perk columbia make morning monitoring appointment ( oppose first come first serve walk time frame lot place )
# 70 additionally procedure do site back surgical room ( oppose going correspond hospital also place seem )
# 71 finally instead taking injection class able sit one one nurse go process
# 72 little things make huge difference throughout experience
# 73 no matter route end taking get pregnant ton appointment involve
# 74 columbia really thought intricacy do great job making streamline possible patient
# 75 million thank ' every single person cross path columbia forever grateful definitely back baby # 2
# 76 take us 4
# 77 5 years get pregnant uterus issue 2 egg retrieval 3 embryo transfer ( 3rd one work !)
# 78 columbia entire time could not happy decision
# 79 make feel welcome fast communicate well
# 80 course bad days hormonal days sad days care team supportive nurse smile try learn name
# 81 dr sinem karipcin ( dr k ) positive warm laugh us good bad times could not recommend columbia
# 82 downside wish dr k could obgyn deliver baby
# 83 doctor talk no action
# 84 spend lot time detailing plan not actually follow
# 85 no thanks place
# 86 husband come columbia fertility terrible experience another fertility doctor manhattan make feel old defective
# 87 arrive columbia fertility impress facility
# 88 welcome bright new everything want clinic
# 89 receptionist nice pleasant
# 90 wait appointment morning monitoring never long
# 91 nurse technician become like friend
# 92 supportive friendly time really need see smile
# 93 dr karipcin doctor amaze
# 94 smart competent dedicate professional
# 95 answer question answer email promptly always positive
# 96 do procedure different patient quickly come see personally review ultrasound speak
# 97 wonderfully compassionate warm person
# 98 lucky work
# 99 always part family
# 100 cannot recommend enough
# 101 wonderful experience primarily dr brady
# 102 beginning till end knowledgeable attentive considerate always easy talk respond question person via email
# 103 thank doctor
# 104 columbia fertility center amaze start seeing le year ago ivf helpful every step way
# 105 specifically patient dr forman bedside manner exceptional
# 106 frequently email serious silly question always answer quickly
# 107 addition make clear care overall health
# 108 even days not schedule perform certain procedure make point anyway patient
# 109 monitoring phase ivf may not always see doctor never make feel uncomfortable warm supportive concern
# 110 lot woman use center fertility / incredible office able manage
# 111 never sat waiting room long time even busy
# 112 great
# 113 husband good fortune connect dr forman journey conception
# 114 day meet dr eric forman positive promise
# 115 never meet attentive caring compassionate empathic doctor facility
# 116 columbia university fertility center invite caregiver
# 117 bless associate dr forman
# 118 husband demand attention doctor team get nothing short
# 119 instead given us promise every appointment respect time answer every question
# 120 best team go looking right doctor ivf
# 121 cannot thank enough
# 122 great experience columbia fertility would highly recommend anyone
# 123 dr rackow care team ( nurse care coordinator ) pleasure work extremely thorough informative
# 124 felt like great hands throughout entire experience
# 125 people front desk always friendly helpful
# 126 dr mcconnell amaze
# 127 extremely patient answer ( detail ) numerous question cross mind
# 128 passionate work reward internally experience patient become mom
# 187 course no one answer phone upon calling
# 188 not blame columbia cycle not working
# 189 maybe not month
# 190 blame not billing situation together
# 191 not need stress life pregnancy
# 192 yet every time see false bill stress level go
# 193 / really not acceptable
# 194 go office first time mainly due seeing jen pheblemist elevator
# 195 express come penthouse check
# 196 happy thus far
# 197 also front desk professional resourceful
# 198 jessica edelith polite sensitive towards knowing reason coming see doctor
# 199 words cannot express gratitude jen
# 200 dr forman one best doctor ' every encounter life
# 201 incredibly knowledgeable attentive warm
# 202 ' patient year cannot say enough good things
# 203 dr forman best doctor
# 204 / pragmatic kind compassionate responsive super top everything
# 205 every person works truly wonderful
# 206 people reception desk amaze
# 207 wait minimal
# 208 really try get easily possible
# 209 jenny take blood kind skilled pleasure
# 210 nurse great
# 211 forever grateful people everything do
# 212 would like recommend dr rogerio lobo one polite patient doctor come across
# 213 also knowledgeable would not simply recommend invasive procedure
# 214 listen well patient ' need provide sound advice
# 215 baby girl not advice care would not go thru challenge beautiful daughter
# 216 thank dr lobo
# 217 dr forman listen concern good first time ivf patient
# 218 nothing small attention / always best
# 219 consistently go beyond entire time care
# 220 perfect example express much want perform actual ivf procedure rather another doctor clinic
# 221 day procedure not guarantee could make rush clinic make happen
# 222 actually tear saw
# 223 things mean world woman no control bad fortune
# 224 team understand things matter difference make concern take seriously
# 225 even front desk nurse draw blood exhibit standard care
# 226 peri egg donor program coordinator especially great
# 227 incredibly helpful reliable
# 228 cannot recommend columbia university fertility center enough
# 229 dr williams amaze dr kind caring compassionate
# 230 would highly recommend practice
# 231 everybody kind caring
# 232 attentive available need
# 233 take time getting know need
# 234 partner dr rachel mcconnell beyond happy
# 235 patient answer question detail thoughtfully always
# 236 pay attention bloodwork scan spot make sure protocol fit
# 237 le yr finally pregnant graduate facility
# 238 bittersweet felt strange bond felt home everyone
# 239 staff scarsdale city best
# 240 always make sure call / email information result sympathetic
# 241 mean antoinette billing katrina nicole always point
# 242 never felt like " next " patient truly like care
# 243 morning monitoring always prompt office well
# 244 truly make experience better tough experience
# 245 could go honestly dr mcconnell simply best knowledgeable especially idea bring attention
# 246 thank hope see everyone double rainbow baby
# 247 finger cross
# 248 live new hampshire feel incredibly grateful refer columbia university fertility center dr williams
# 249 care receive dr williams team unlike
# 250 caring kind brilliant progressive
# 251 dr williams make available hours day express sincere intent care
# 252 rarely find doctor feel invest case dr williams group exceed expectation
# 253 front desk staff billing team clinical team blow away
# 254 thank do family truly truly grateful
# 255 omg practice think get away horrible review rebranded get nice lil makeover place still crappy
# 256 doctor suck not give shit never return call
# 257 billing system terrible still receive bill 2013
# 258 place suck
# 259 save aggravation frustration heartbreak
# 260 husband try conceive little 2 years
# 261 unsure begin start daunt process decide meet dr columbia essentially take leap faith
# 262 end two ( fail ) cycle iui last year doctor first meet columbia
# 263 research decide switch dr eric forman first ( successful !!) ivf cycle happy
# 264 truly understanding personable amaze communication response time no question inconsequential complicate explain super informative
# 265 quality separate doctor mind give constant reassurance confidence chosen right doctor staff facility
# 266 could not recommend dr forman enough
# 392 not know cryopreservation not cover either costs 1250 never mention 1 ) cryopreservation 2 ) cost even eventuality not cover
# 393 procedure ask billing department everything ok receive pre authorization
# 394 say not yet everything cover except testing
# 395 receive pre authorization 6 days cryopreservation not cover know pay pocket
# 396 try reach billing department several times not address question want acknowledge fact notify eventuality cost
# 397 genetic testing push
# 398 thinking horrible pushy experience doctor want make money child sure do purpose
# 399 another fertility clinic oradell night day !!! also research new hope way handling business definitely borderline
# 400 case would not recognize clinic experience similar issue please reach
# 401 would love investigate
# 402 one worst doctor experience ' ever
# 403 cannot say enough horrible things place
# 404 long please read not want happen anyone else
# 405 first meet doctor nice talk 5 minutes ultrasound
# 406 not hear anything history even ask often sex ( something think / would probably want start )
# 407 ultrasound say " look like may endometriosis
# 408 " end conversation
# 409 come back saline test spoke nurse tell come test result
# 410 make wait 2 hours get saline test come read genetic test result
# 411 ask several people waiting make sure know reason tell come genetic test reading
# 412 confirm state would minutes
# 413 finally husband go spoke someone 2 hours take see doctor genetic result
# 414 apologize confusion say test would perform right away
# 415 go testing room tell doctor scare hear may hurt
# 416 reply " ultrasound ??" say
# 417 no saline test
# 418 let know come " much late " not follow instructions provide
# 419 tell nurse ask day cycle would say fine come
# 420 tell " oh not listen
# 421 not know / talking
# 422 " ok / terrify
# 423 tell " uneducated ," say would still able perform test today magically
# 424 suddenly let know actually would able start fertility treatment following day
# 425 really shock tell need hsg test see tube block still want move forward
# 426 say ovulate come tomorrow morning start
# 427 issue one not recommend test yet two use opk wake day test not ovulate ( though know not / not 100 % accurate ), third new hope not enroll aetna ' fertility program
# 428 since not getting treatment yet not enrol would pay pocket lastly tell might endometriosis not even going look needle say left hysterically crying never go back
# 429 make already vulnerable situation way worse
# 430 going kofinas fertility / amaze
# 431 doctor sat us 45 minutes go history detail ' waiting get help endometriosis think problem start fertility treatment
# 432 hate go awful degrade experience however lead us kofinas blessing disguise
# 433 think fact stay open throughout entire coronavirus pandemic say lot business philosophy
# 434 clearly protect staff patient contribute safety general public not part mo
# 435 money mo
# 436 dentist close clinic donate ppe near hospital
# 437 left new hope years ago glad
# 438 poorly run impersonal
# 439 half staff nice courteous helpful
# 440 half hate job take patient
# 441 one ultrasound tech rude sullen dismissive days one colleague apologize saying " bad week
# 442 " no excuse period
# 443 part staff functional nice efficient phlebotomist -- professional whole well train
# 444 medical decision make nurse sort protocol
# 445 definitely not individualize
# 446 find interest cynthia b write great review employee
# 447 several " great " review people not write review ( hmmm could bias employee fake account sing glory place employment ?)
# 448 meet dr jackman couple week ago initial consultation
# 449 start " educational session " turn full blow sales pitch ivf treatment
# 450 towards end session ( 1
# 451 5 hours full blow sales pitch ), immediate question " put ivf treatment ?"
# 452 not even go initial fertility testing see even necessary
# 453 couple week ' later get notice office see start cycle
# 454 no indication intention better understand fertility treatment even need
# 455 try put pressure need start treatment immediately / not waste time categorize us " infertile " no warrant fact ; try prey couple ' fear fail miserably see many couple ' try much longer time easily fall tactic
# 456 would strongly caution anyone looking start journey practice
# 457 find dr use proper measure come non invasive / cost effective treatment plan
# 458 plan writing review procedure however decide early
# 459 though wary coming due negative comment decide try anyway " quality v
# 460 quantity " philosophy
# 461 come low expectation customer service doctor " bedside manner " like however much blow away treat
# 462 consultation dr olcha clearly drew diagram ipad explain everything partner
# 463 treat well phlebotomist nurse transvaginal ultrasound
# 464 never latter do nurse explain everything process well seeing screen
# 465 partner really enjoy experience doctor team
# 466 thought maybe nice / first visit
# 467 nope ' go least handful times ( even future ) every time professional respectful experience
# 468 not center question send email
# 469 email promptly respond email dr olcha email back right away get fast response dr olcha work colleague lolz
# 470 originally going iui route however ivf
# 471 not sure outcome never please new hope
# 472 speak people infertility problem happily recommend nhfc
# 473 far happy fertility clinic fifth one
# 474 doctor zhang attentive passionate hopeful realistic time
# 475 seem look case individually not following protocol find case clinic treat like number kettle no reasoning mind
# 476 monitoring early morning speaking doctor award ask
# 477 clinic pleasant large windows columbus circle part central park natural light always welcome going hard times
# 478 system efficient well allow high demand not leave us lost midst infertility fog
# 479 good luck lady wishing success ' hard journey !!!
# 480 thanks dr merhi nhfc staff get beautiful healthy ​ baby girl ​ age 39
# 481 going back dr merhi # 2
# 482 wish luck writing ​ review would like express appreciation ​ dr merhi
# 483 really best doctor meet life
# 484 kind compassionate ​ positive ​ vibe professional ​​ time ​​
# 485 listen ​ propose ​ best option
# 486 long story short problem nhfc dr merhi call make sure everything ok
# 487 time learn ​ doctor really care ​ patient ​
# 488 nhfc believe good clinic
# 489 ​ ​ great facility ​, skilled staff method ​​ perform ​ ton success case
# 490 generally work quick efficient
# 491 hand also agree people ​ organize structure bit
# 492 example procedure not get enough information ​ need google every day ​ understand things
# 493 wish explain better enrich website ​ article form
# 494 billing department not big issue cost expect cost well get handout fee first consultation
# 495 however many hide fee ( mostly cover insurance no big deal )
# 496 minor problem unless ask ​ receipt ​, billing department never sent
# 497 thus long time not know much pay
# 498 charge ​ credit card
# 499 hope ​ billing department send ​ receipt ​​ every time ​ use file credit card
# 500 overall definitely ​ recommend ​ nhfc especially ​ wonderful ​ doctor ​ dr merhi
# 501 thank much best people ​ consider ​ go nhfc
# 502 update : use recommend place everyone really struggle keep dr zhang really good
# 503 ' ( mostly ) good experience
# 504 bit factory need take responsibility raising flag know something not work body
# 505 ' tell certain things not work protocol given
# 506 ' do half dozen round point ' learn things body
# 507 say major weakness
# 508 / significant one
# 509 billing department
# 510 guy not seem good job ( not submit insurance long period time sending surprise bill year later ) friendly responsive
# 511 outright ignore email phone call message front desk etc
# 512 not care
# 513 make mistake still treat like jerk
# 514 ineptitude cost company lot money
# 515 know bc major barrier not come round freezing
# 516 ' cover insurance job make easy possible ( everything work insurance ) get people
# 517 / revenue generate
# 518 not know doctor know much team hinder profits hope see figure soon
# 519 would give 5 star not billing team
# 520 update : nhfc come back say error outsource billing company
# 521 zero ed charge account appreciate rectify mistake
# 522 say would hesitant come back actual procedure since hate surprise unexpected bill / charge revise 1 star 3 customer remediation
# 523 really lovely people compassionate team medical professional
# 524 mention often frequently friend
# 525 try get pregnant familiar things need look : health uterus fallopian tube hormone distribution
# 653 found famous doctor nj try round artificial insemination 3 ivfs total fail
# 654 sort test result not bad not great either
# 655 tell prospect look dismal think donor eggs surrogacy adoption
# 656 try donor eggs 20 embryo transfer end miscarriage one
# 657 along way 10 + precious years pass
# 658 time hopelessness come across new hope dr zhang
# 659 first thing dr zhang tell us " no problem test good need nourish body get ready "
# 660 analogy use need fertile ground first implant seed
# 661 " ' confident get pregnant within 6 12 month "
# 662 oh boy not try hard " get ready " exercise diet emotional balance herb medicine
# 663 month tell ready
# 664 6 month egg retrieval 4 freeze embryo
# 665 continue physical exercise jogging keeping fit lose weight half year
# 666 come transfer insist 2 embryo though dr zhang suggest 1 since 43 time consider high risk case
# 667 end lo behold successfully 2 beautiful baby although pregnancy process somewhat eventful bleeding scare kidney trouble bedridden order
# 668 hey make years pain desperation really proud 2 kid nutshell grateful dr zhang make dream come true conviction combining western technology chinese cultivation / nourishment methodology
# 669 update initial review
# 670 try baby # 2 disappoint experience
# 671 not know get busy pregnancy last time matter fate
# 672 moment really need see doc ofcourse not happen
# 673 cycle fail nurse advise meet dr zhang next steps
# 674 doc need one last viable embryo
# 675 wish get better care
# 676 feel like nurse really handle care time without consult doctor
# 677 great facility good experience staff care ivf journey
# 678 still process undergo procedure hopeful
# 679 one setback anesthesia
# 680 facility let patient go home one hour ivf sedation
# 681 sign waiver end procedure state going home alone
# 682 understand many patient not someone take home especially since procedure schedule day
# 683 something need change dangerous suboptimal delivery care
# 684 maybe provide chaperone stress importance someone take home procedure
# 685 rating zero
# 686 facility waste time money
# 687 doctor not follow case nurse one sending email saying doctor saying
# 688 start year ago follicle reaching size 15 year later could not detect not one
# 689 feel not know
# 690 number care not customize
# 691 left exam table waiting doctor explain year later no follicle
# 692 left unattended exam table
# 693 physician never come appointment see
# 694 30 minutes decide leave realize forget
# 695 hours past no one call see go restroom see even left
# 696 " false hope facility " seem string along not come sense
# 697 entire year saw doctor 4 times
# 698 great overall fertility center huge staff thats always willing help
# 699 sonogrophers nurse particularly knowledgeable great coming ultrasound morning
# 700 end seeing dr olcha great hold hand whole process
# 701 nhfc approach could care le
# 702 persistently calling speak someone embryo calling days
# 703 not single person call back
# 704 spite repeat call pleading someone call back time sensitive issue question silence nhfc
# 705 place need advocate hope / best get
# 706 billing department vigilant chase invoice wish doctor would well
# 707 fed place
# 708 no one call back no matter journey / treatment
# 709 not get call everyone doctor people process insurance billing
# 710 no one say going ( ie call back process insurance call pharmacy ) doctor sometimes
# 711 find place else
# 712 still waiting get call back need next round med desperately
# 713 process timing make already try process needlessly excruciate frustrate expensive
# 714 feel like assembly line waiting room like dmv literally waiting name number call
# 715 disappoint sell " hope " realistically stats numbers come slowly reveal little le hopeful realistic
# 716 dr merhi lovely
# 717 straightforward give practical advice situation follow successful natural iui first try
# 718 hello
# 719 finish 4th cycle
# 720 take break mentally prepare
# 721 4th cycle experience restart cycle 2 times
# 722 let explain
# 723 know want one doctor follow case
# 724 request doctor every monitoring
# 725 get instructions first monitoring expect instructions
# 726 ask take clomid
# 727 following monitoring tell follicle go
# 728 could not get doctor speak us
# 729 tell monitor continue take birth control pill via email instructions
# 730 doctor part two 4th cycle
# 731 take birth control pill
# 732 follicle recruitment expect
# 733 ask doctor follow
# 734 following instructions take clomid gonal
# 735 didnt want repeat history
# 736 stern taking medication
# 737 ask speak doctor
# 738 no good response
# 739 purchase gonal expensive
# 740 result follicle lost
# 741 disappoint may expect
# 742 finally get speak doctor
# 743 nice phone ask us try
# 744 part three 4th cycle
# 745 end result
# 746 found doctor not monitoring us like request
# 747 doctor admit another doctor look case vacation
# 748 doctor not know wife ' reaction clomid
# 749 recommend clomid intake high times burn follicle
# 750 no one come talk us till ready 5th cycle
# 751 doctor always busy
# 752 want think happy thought
# 753 nhfc may working lot couple today
# 754 doctor busy egg retrieval
# 755 nhfc not working us
# 756 getting good bad indifferent result please pm
# 757 want learn experience ask maybe conversation invaluable
# 758 wish best
# 759 come start family grow family
# 760 part journey wish experience good one
# 761 not go first time seeking treatment
# 762 not explain anything respond inquiry zero personal attention
# 763 number factory
# 764 treat big fertility clinic nj going new hope
# 765 recommend treatment using donor eggs first consultation clinic nj treatment not even start 43
# 766 going thru conventional 2 ivfs decide change clinic depress hopeless since could not get blastocyst
# 767 also clinic nj make feel pressure use donor eggs uncomfortable continue treatment due age
# 768 first ivf nhfc get one blastocyst give us hope
# ...
# 5709 funny pregnant without assistance within 2 week consultation
# 5710 dr shah much better understanding approach diminish ovarian reserve
# 5711 guess / happen focus job helping precook not bottom lobe
# 5712 search read bad review go penn fertility clinic
# 5713 huge disappoint us do eggs retrieval september 2017 embryo not last blastocyst / mean no embryo transfer no partial refund either accord policy agreement
# 5714 call asking explanation no one call back email embryologist say talk dr
# 5715 barnhart apparently spoke couple times start ivf program everything nurse
# 5716 respond email nurse call next day set meeting explanation
# 5717 long story short ask gonna able healthy baby everything normal say husband morph abnormal little bit
# 5718 !! mean know beginning would not start ivf program gonna fix issue first continue
# 5719 feel like want get money first not care feelings
# 5720 without going much detail let us say due age due nature problem probably around 20 30 % chance carry pregnancy full term
# 5721 fact change fertility clinic penn previous doctor ( shall remain nameless let us say base bryn mawr hospital ) not good manner explain us
# 5722 well aware odds us basically act like us favor even try treat us chance would not work
# 5723 discourage
# 5724 top error staff making care experience stink location
# 5725 research decide switch penn
# 5726 see way explain things realistic manner yet positive way encourage instead discourage
# 5727 doctor deal penn excellent
# 5728 truly felt like staff rooting us instead treat us like burden due circumstances
# 5729 bottom line
# 5730 despite odds us healthy son born last month due care receive penn
# 5731 first thing ' like say anyone looking fertility intervention read ' making baby ' sami david & jill blakeway
# 5732 first chapter need read understand happening penn fertility care
# 5733 go february 2016
# 5734 no issue staff everyone seem professional actually bit rehearse
# 5735 feel bit like science project first visit ton blood take testing transvaginal ultrasound schedule hsg next day
# 5736 hsg perform show fallopian tube block
# 5737 result given right do sitting front 4 stranger ( not sure 4 people need room )
# 5738 obviously completely devastate little compassion doled
# 5739 worst part come alone tell could simple outpatient service
# 5793 dr dokras perform transfer thorough talking everything
# 5794 ' also work dr butt laparoscopy
# 5795 would recommend
# 5796 especially endometriosis
# 5797 not go !!! go iui tell 20 minutes later doctor not need go city
# 5798 tell sample must get within hour not case time ???!!!! another occasion nurse laugh talking infertility
# 5799 place need serious sensitivity professionalism training
# 5800 never treat disrespect lack compassion stressful painful time
# 5801 treat like number get test straight iui
# 5802 practice disgrace
# 5803 husband go see dr dokras infertility treatment
# 5804 refer penn fetal medicine fantastic experience
# 5805 continue high opinion penn fetal medicine
# 5806 terrible experience dr dokras
# 5807 uneducated unsympathetic need
# 5808 initial appointment decide go another fertility center philadelphia
# 5809 amaze experience fertility center
# 5810 would not recommend facility
# 5811 shock disappoint lack knowledge attention sensitivity experience
# 5812 many great facility treat respect care deserve
# 5813 unfortunately not one
# 5814 leave review practice experience nothing like previous reviewer
# 5815 wonderful compassionate timely care office ( 3701 market street )
# 5816 patient office two years
# 5817 doctor dr dokras
# 5818 actually two head receptionist madeline teresa incredibly kind many interaction person phone
# 5819 yes wait 25 minutes occasion not norm
# 5820 visit include visit get blood work wait 5 minutes
# 5821 reason not always see doctor upenn teaching hospital office fellowship program doctor become instructor
# 5822 fellow currently physician field wonderful bedside manner something extremely important fertility patient
# 5823 experience fellow thorough communicative attending physician compassionate
# 5824 visit see fellow also see doctor well
# 5825 also request see doctor prefer
# 5826 however found seeing doctor great working team care
# 5827 ( two head better one !) always get call nurse ( nurse susan rock !!) day call visit always follow care
# 5828 always detail instructions plan ( something also important fertility patient
# 5829 ) dismiss office due previous review please check
# 5830 may love like
# 5831 mean scathing not mean dr butt wish assign doctor kind nurse
# 5832 majority penn fertility staff however treat husband terribly really difficult time
# 5833 run standard battery test charge us twice never explain anything
# 5834 three fail iui procedure ; time penn charge us co pay $ 150 " specimen thaw " part co pay fertility clinic
# 5835 could almost never get touch doctor nurse want times could rush phone
# 5836 receptionist often rude unintelligent unhelpful
# 5837 final straw : test show fallopian tube might blockage meaning procedure do quite possibly complete waste time tears money : doctor never tell
# 5838 look report research every unfamiliar medical term interpret report
# 5839 husband go shady grove fertility thrill switch
# 5840 though left practice december receive several harass enormous bill resolve
# 5841 penn abuse try rob
# 5842 go clinic human decency incredibly emotional try time
# 5843 ' switch mainline fertility wise choice
# 5844 would given 5 star wait time better offer 7
# 5845 lab time office
# 5846 receive respect superb care front desk staff doctor
# 5847 main dr dr barnhart wonderful receive care dr butt dr dokras dr coutafaris ( name misspell ), / head doctor
# 5848 getting run around mainline could change protocol immediately figure milk money insurance since pay ivf dr barnhart review history change protocol everything go smoothly
# 5849 ' 4 days past 3 day embryo transfer
# 5850 dr dokras let view screen transfer explain everything step step
# 5851 severe endo issue high estrogen low ovarian reserve 34 yr old dr dokras transfer 2 grade 1 8 cell embryo
# 5852 ' expect positive pregnancy test next week
# 5853 cute negative review practice dismiss " not recommend "
# 5854 actually contain valuable point patient
# 5855 overall level service uneven
# 5856 first give place nickname " hot mess happy ending "
# 5857 miscommunicate
# 5858 completely forget coming fro initial appointment casually show 45 minutes past schedule time not review chart
# 5859 occasionally give wrong dose med --
# 5860 " stay 450 unit ", dose actually 300 unit prepare doublecheck every step
# 5861 pleasant heart right place system overall effective
# 5862 thought le 24 hours last retrieval tell no donor sperm prepare
# 5863 means airhead nurse not bother check le one day procedure sunday afternoon
# 5864 honestly bit much take
# 5865 end found sperm procedure last minute gown iv know procedure still happening
# 5866 prepare lot stress omission
# 5867 still achieve result close group center city people geographically become important us bloodwork every day
# 5868 people like : drs shah kalra garcia ; nurse erin rie ( professional ), us tech -- think name julie receptionist actually treat nice accomodating need ( take early train thus cut line coupla times )
# 5869 keeba biller also approachable help wrongly file bill
# 5870 egg donor
# 5871 amaze !!! never wait 5 minutes waiting room
# 5872 nurse take blood amaze !!! never feel never get bruise treat respect care
# 5873 never experience doctor actually take time get know really care no health problem donate !!! love
# 5874 please penn fertility
# 5875 interview several fertility clinic ultimately choose penn could not happy
# 5876 sex couple need egg donor surrogate
# 5877 third party coordinator amaze helping us coordinate move piece surrogacy journey even kink throw unexpectedly
# 5878 dr g also gem helping us work le typical situation arise
# 5879 make available throughout process need
# 5880 incredibly appreciate emotional process
# 5881 ultimately successful pregnancy first try baby within year first visit clinic
# 5882 cannot happy moon little bundle joy
# 5883 plan using penn make big brother soon
# 5884 interaction one doctora practive left feeling dismiss unvalued
# 5885 whenever discussion ivf come inform dr not option would shut
# 5886 one comment well even something fix age may not get pregnant
# 5887 next conversation reply going go nature ' course
# 5888 bedside manner unprofessional ; upon pelvic exam never advise insert speculum finger
# 5889 tell visit er two days prior due unusual discharge first tell stop taking antibiotic tell keep taking intercourse night call let know issue persist
# 5890 thatm say fine pretty sure ' fine keep post
# 5891 even though not prusing ivf believe practice one best country would not recommend dr sondheimer
# 5892 absolutely horrible
# 5893 wait simply unprofessional uncalled
# 5894 fiancé attending penn fertility year
# 5895 already extremely distraught experience miscarriage fail iui '
# 5896 deal unpleasant receptionist sit rooms alone 30 90mins waiting doctor nurse incredibly frustrate
# 5897 especially multiple times week
# 5898 avoid center city location costs
# 5899 doctor ( drbutts ) knowledgable barely get see ever rush interaction leave question concern afterwards
# 5900 run lengthy trial know fail finally prescribe correctly
# 5901 top things expect result basically call / bug
# 5902 place complete waste time
# 5903 avoid possible
# 5904 penn fertility absolutely terrible
# 5905 go 8 month barely run test husband
# 5906 saw doctor twice usually nurse dr
# 5907 not even call hsg
# 5908 ask try fertility med one month ( not recommend even mention ) nurse give without explanation
# 5909 felt completely alone unmonitored
# 5910 not blood test ultrasound throughout month
# 5911 little oversight
# 5912 first clear experience almost exclusively 3701 market street not location
# 5913 one initial visit radnor want care ( per website location interchangeable yeah right !)
# 5914 come another fertility practice saw doctor visit shock never see doctor doctor nurse visit
# 5915 could comfortable arrangement felt easy access nurse doctor ways felt disconnect care without power ask simple question get feedback
# 5916 doctor nurse fine review would given 3 1 / 2 4 star
# 5917 since really not much sway regular visit office give 1 star
# 5918 wait terrible never le 25 minutes sometimes hour
# 5919 maybe not big deal doctor ' office fertility testing occur every day need able get quickly
# 5920 case getting blood work do ( take le 2 minutes )
# 5921 previous clinic usually wait le 10 min worst wait 4 month 30 minutes ( apologetic )
# 5922 not penn fertility
# 5923 wait better not ask question
# 5924 reason low rating receptionist
# 5925 quiet follower typer personality happy tell long ' not mistreat
# 5926 main receptionist 3701 penn fertility care one nasty woman ever meet
# 5927 bark almost every time come
# 5928 great day away desk office someone else step possess common courtesy
# 5929 may seem like small thing guard dog office nearly impossible see talk anyone without getting past
# 5930 singlehandedly make visit incredibly frustrate unpleasant ( already stressful b / c undergo fertility treatment duh !)
# 5931 insurance require go penn fertility care no choice
# 5932 choice suggest run another practice ( try rma )
# 5933 penn fertility care knowledgeable informative flexible husband navigate tricky fertility process
# 5934 ' middle treatment not pregnant yet never consider going anywhere else -- not get sense numbers think care individual patient case try develop protocol work individual
# 5935 also individualize billing approach -- explain bill ask person come rather receive random disconnect bill
# 5936 doctor excellent -- get treatment inclement weather meaning doctor switch around schedule -- always available us
# 5937 nursing staff way
# 5938 nurse communicate via text need although not realize much process would do nurse / important feel comfortable nurse

# %%
for i, r in enumerate (df_yelp_split.clean_answers):
    if len(r) < 10:
        print (r)
        df_yelp_split.drop(i,axis=0,inplace=True)
# Out:
# feel like
# family
# recommend
# great
# thank
# happy far
# nhfc try
# care
# know talk
# money mo
# care
# let pcos
# wait mum
# rate zero
# feel know
# fed place
# 4th cycle
# nhfc work
# wish well
# response
# work dr
# new hope
# wait long
# 39 time
# s nice
# busy time
# 100 worth
# good luck
# honest
# hormone
# deal care
# feel
# like tell
# expect
#
# infuriate
#
# idea
# star
# feel rush
# wile take
# comfort
# home
#
# email
# time pass
# hear
# think odd
# 3rd work
# penny
#
# watch
# wait long
#
# excellent
# mean
# 5 go 5 7
# important
# positive
# factory
# guy quit
# hear
# bizarre
# stressful
# thank nyu
# extract
#
# tiny
# try worry
# job
# know
# nyu well
# let well
# team
# time
# thank
# afternoon
# treat 7
# place a
# calls
# shame
# cash cow
# patience
# pregnant
# rma wrong
# fantastic
# want dr
# 4 star
# wish 4
# find fax
# rma tell
# ivf glad
# glad
# u kid
# place
# like hate
# horrible
# recommend
# stressful
# agree say
# get
# go
# pron pron
# believe
# recommend
# crazy
# work
# stop go
#
# etiquette
# forget
# cancer
# ask hurt
# zero star
# nice cry
# numb
# say
# kid
# doctor 2
# star dr
# lightly
# work
# love
# place
# stress
# brilliant
# best wish
# hear like
#
# charge
#
# get well
# pay
# helpful
# ask
# crook
# ti work
# thank
# care
# clinic
# wrong
# office
# bad place
#
# okay
#
# let
#
# care
# advice
# pregnant
# nurse day
# good hand
# hope
# patience
# question
# believe
# best luck
# know
# sort
# waste 30k
# numb
# wait
# use
# butcher
# fool
# spouse
#
# great job
# zero star
# work find
# go sure
# go leave
# numb
# cold rude
# love doc
# favor
#
# properly
#
# meet pa
# best luck
# big issue
# 200 even
# unwilling
# run late
#
# thank
# story
# get well
# line
# fact tell
# recommend
# love like
# egg donor
# hsg

# %%
df_yelp_split.to_csv('yelp_clean.csv')
